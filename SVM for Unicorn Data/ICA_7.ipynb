# %%
import os
import sklearn
import numpy as np
from numpy import unwrap, diff, abs, angle
import pandas as pd
import seaborn as sns
import tensorflow as tf
from sklearn.svm import SVC
import matplotlib.pyplot as plt
from scipy.signal import hilbert
from sklearn.utils import shuffle
import scipy
from scipy.signal import butter, filtfilt, hilbert
from scipy.interpolate import interp1d
from scipy.interpolate import CubicSpline
from tensorflow.keras.models import Sequential
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import classification_report
from imblearn.over_sampling import RandomOverSampler
from sklearn.model_selection import train_test_split
from keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from sklearn.metrics import accuracy_score, classification_report
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from tensorflow.keras.layers import Dense,  BatchNormalization, Dropout
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
import mne
from mne.preprocessing import ICA
import pywt
from scipy.stats import skew, kurtosis
from scipy.signal import spectrogram
from mne.viz import plot_topomap
from scipy.signal import welch
import matplotlib.pyplot as plt

# %% [markdown]
# Preproccesing Functions

# %%
def butter_bandpass(lowcut, highcut, fs, order=5):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    return b, a

def butter_bandpass_filter(data, lowcut, highcut, fs, order=5):
    b, a = butter_bandpass(lowcut, highcut, fs, order=order)
    y = filtfilt(b, a, data)
    return y

def denoise_data(df, col_names, n_clusters):
    df_denoised = df.copy()
    for col_name, k in zip(col_names, n_clusters):
        df_denoised[col_name] = pd.to_numeric(df_denoised[col_name], errors='coerce') # Convert column to numeric format
        X = df_denoised.select_dtypes(include=['float64', 'int64']) # Select only numeric columns
        clf = KNeighborsRegressor(n_neighbors=k, weights='uniform') # Fit KNeighborsRegressor
        clf.fit(X.index.values[:, np.newaxis], X[col_name])
        y_pred = clf.predict(X.index.values[:, np.newaxis]) # Predict values 
        df_denoised[col_name] = y_pred
    return df_denoised

def z_score(df, col_names):
    df_standard = df.copy()
    for col in col_names:
        df_standard[col] = (df[col] - df[col].mean()) / df[col].std()
    return df_standard

def custom_detrend(df, col_names):
    df_detrended = df.copy()
    for col in col_names:
        y = df_detrended[col]
        x = np.arange(len(y))
        p = np.polyfit(x, y, 1)
        trend = np.polyval(p, x)
        detrended = y - trend
        df_detrended[col] = detrended
    return df_detrended

def preprocess(df, col_names, n_clusters):
    df_new = df.copy()
    df_new = denoise_data(df, col_names, n_clusters)
    return df_new

def df_to_raw(df, sfreq=250):
    info = mne.create_info(ch_names=list(df.columns), sfreq=sfreq, ch_types=['eeg'] * df.shape[1])
    raw = mne.io.RawArray(df.T.values * 1e-6, info)  # Converting values to Volts from microvolts for MNE
    return raw

def reject_artifacts(df, channel):
    threshold_factor = 5
    median = df[channel].median()
    mad = np.median(np.abs(df[channel] - median))
    spikes = np.abs(df[channel] - median) > threshold_factor * mad
    x = np.arange(len(df[channel]))
    cs = CubicSpline(x[~spikes], df[channel][~spikes]) # Interpolate using Cubic Spline
    interpolated_values = cs(x)
    interpolated_values[spikes] *= 0.1  # Make interpolated values 0.1 times smaller
    spike_values = np.abs(interpolated_values - median) > threshold_factor * mad
    interpolated_values[spike_values] *= 0.001 
    df[channel] = interpolated_values
    return df

def plot_eeg_data(before, after, title, colors):
    """Plots EEG data."""
    plt.figure(figsize=(12, 8))
    for i in range(before.shape[1]):
        plt.plot(before[:, i] + i * 200, color=colors[i])  # Offset added for visualization clarity
    for i in range(after.shape[1]):
        plt.plot(after[:, i] + i * 200, color=colors[i], linestyle='--')
    plt.title(title)
    plt.xlabel('Time (samples)')
    plt.ylabel('Amplitude')
    plt.show()

# %% [markdown]
# Define the dataset

# %%
# Creating a new folder for spike rejected data
new_folder = 'spike_rejected_data'
if not os.path.exists(new_folder):
    os.makedirs(new_folder)    
folder_name = 'ES_1'
selected_columns = ['Fz', 'C3', 'Cz', 'C4', 'Pz', 'Po7', 'Oz', 'Po8']

# %%
subfolder_name = 'spike_rejected_data'
# Full path to the subfolder
spike_rejected_folder = os.path.join(folder_name, subfolder_name)
duration = 40 
EEG_Before_ICA = []
event = []
totaldata = []
face = []
scene = []
baserejected=[]
if os.path.exists(spike_rejected_folder) and os.path.isdir(spike_rejected_folder):
    for file_name in os.listdir(spike_rejected_folder):
        if file_name.endswith('.csv'):
            file_path = os.path.join(spike_rejected_folder, file_name)
            s_temp = pd.read_csv(file_path, header=0)
            totaldata.append(s_temp)
            instruction = s_temp.iloc[:, 8]

            baseline = s_temp[s_temp.iloc[:, -1].isin(['b', 'g'])].iloc[:, :-1]
            baseline_avg = baseline.mean()

            non_baseline_data = s_temp[~s_temp.iloc[:, -1].isin(['b', 'g'])]
            inst_activity=non_baseline_data.iloc[:, 8]
            # print('inst_base_rej', inst_activity)
            adjusted_non_baseline = non_baseline_data.iloc[:, :-1] - baseline_avg
            
            concatenated = pd.concat([baseline, adjusted_non_baseline], ignore_index=True)
            s_temp_baseline_rejected= pd.concat([concatenated, instruction], axis=1) 
         
            activity_baseline_rejected_with_inst= pd.concat([adjusted_non_baseline, inst_activity], axis=1) 

            baserejected.append(activity_baseline_rejected_with_inst)
            # Check if the last column contains 'I' or 'O'
            if 'I' in instruction.values or 'O' in instruction.values:
                scene.append(s_temp_baseline_rejected)
                
            if 'M' in instruction.values or 'F' in instruction.values:
                face.append(s_temp_baseline_rejected)  
                          
            df_temp = s_temp.iloc[:, :8]
            EEG_Before_ICA.append(df_temp)
            event.append(instruction)

# %%
baserejected_np = np.vstack(baserejected)
label_brj = baserejected_np[:, -1:]

labels=[]
for i in range(len(baserejected_np)): #len(pp_sig_event) = the whole sample points, (df_temp.shape[0]*B_N)
    if 'M' in baserejected_np[i, 8] or 'F' in baserejected_np[i, 8]:
        labels.append(0)
    if 'I' in baserejected_np[i, 8] or 'O' in baserejected_np[i, 8]:
        labels.append(1)

labels=np.array(labels)

# Array with all columns except the last
rest_of_baserejected_np=baserejected_np[:, :-1]

baserejected_np_reshaped=rest_of_baserejected_np.reshape(int(baserejected_np.shape[0]/250), 250*8)
label_brj_reshaped=labels.reshape(int(baserejected_np.shape[0]/250), 250)

# %%
af_mlp=baserejected_np_reshaped
Y_mlp=np.squeeze(label_brj_reshaped[:,0])
af_mlp, Y_mlp= shuffle(af_mlp, Y_mlp)
print(af_mlp.shape, Y_mlp.shape)
# Balance the dataset
oversampler = RandomOverSampler(sampling_strategy='auto', random_state=42)
X_resampled_mlp, y_resampled_mlp = oversampler.fit_resample(af_mlp, Y_mlp)
X_resampled_mlp= X_resampled_mlp.astype(np.float32)
y_resampled_mlp = y_resampled_mlp.astype(np.int32)

X_train, X_test, y_train, y_test = train_test_split(X_resampled_mlp,y_resampled_mlp, test_size=0.2, random_state=42)
# Out:
# (820, 2000) (820,)

# %%
import optuna
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split


def objective(trial):
    # Layers and neurons
    n_layers = trial.suggest_int('n_layers', 1, 3)
    layers = []
    for i in range(n_layers):
        layers.append(trial.suggest_int(f'n_units_layer{i}', 16, 512))
    
    # Activation function
    activation = trial.suggest_categorical('activation', ['relu', 'logistic', 'tanh', 'identity'])
    
    # Learning rate
    learning_rate_init = trial.suggest_float('learning_rate_init', 1e-4, 1e-1, log=True)
    
    max_iter = trial.suggest_int('max_iter', 50, 1000)

    # Stratified K-Fold cross-validation
    kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    accuracies = []

    for train_index, val_index in kf.split(X_train, y_train):
        X_train_fold, X_val_fold = X_train[train_index], X_train[val_index]
        y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]

        model = MLPClassifier(hidden_layer_sizes=tuple(layers), 
                              activation=activation, 
                              learning_rate_init=learning_rate_init,
                              max_iter=max_iter, 
                              random_state=42)

        model.fit(X_train_fold, y_train_fold)

        # Evaluate
        predictions = model.predict(X_val_fold)
        accuracies.append(accuracy_score(y_val_fold, predictions))

    # Average accuracy across all folds
    return sum(accuracies) / len(accuracies)

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=70)

print('Number of finished trials: ', len(study.trials))
print('Best trial:')
trial = study.best_trial
print('  Value: ', trial.value)
print('  Params: ')
for key, value in trial.params.items():
    print(f'    {key}: {value}')

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split


# Extract the best parameters from the study
best_params = study.best_trial.params

# Extract individual parameters
n_layers = best_params['n_layers']
layers = [best_params[f'n_units_layer{i}'] for i in range(n_layers)]
activation = best_params['activation']
learning_rate_init = best_params['learning_rate_init']
max_iter = best_params['max_iter']

# Stratified K-Fold cross-validation on training data
kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
cv_train_accuracies = []

for train_index, val_index in kf.split(X_train, y_train):
    X_train_fold, X_val_fold = X_train[train_index], X_train[val_index]
    y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]

    # Create the model using the best parameters
    model = MLPClassifier(hidden_layer_sizes=tuple(layers), 
                          activation=activation, 
                          learning_rate_init=learning_rate_init,
                          max_iter=max_iter, 
                          random_state=42)

    # Train the model using a training fold
    model.fit(X_train_fold, y_train_fold)

    # Predict using the validation fold
    val_predictions = model.predict(X_val_fold)
    cv_train_accuracies.append(accuracy_score(y_val_fold, val_predictions))

# Average accuracy across all training folds
avg_cv_train_accuracy = sum(cv_train_accuracies) / len(cv_train_accuracies)
print(f"Average CV Training Accuracy: {avg_cv_train_accuracy:.4f}")

# Train the model using the entire training data
final_model = MLPClassifier(hidden_layer_sizes=tuple(layers), 
                            activation=activation, 
                            learning_rate_init=learning_rate_init,
                            max_iter=max_iter, 
                            random_state=42)
final_model.fit(X_train, y_train)

# Predict using the untouched test data
test_predictions = final_model.predict(X_test)
test_accuracy = accuracy_score(y_test, test_predictions)
print(f"Test Accuracy: {test_accuracy:.4f}")

# %%
face_np=np.array(face)
scene_np=np.array(scene)
face_0_np= face_np[0].to_numpy()
face_0_np_reshape=face_0_np.reshape(face_0_np.shape[1], 250, int(face_0_np.shape[0]/250))
face_0_np_reshape.shape
# Out:
# C:\Users\Maryam\AppData\Local\Temp\ipykernel_87560\876255597.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   face_np=np.array(face)
# C:\Users\Maryam\AppData\Local\Temp\ipykernel_87560\876255597.py:2: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   scene_np=np.array(scene)
# (9, 250, 37)

# %%
face_np[0].shape
# Out:
# (9250, 9)

# %%
for i in range (len(face_np)):
    face_i_np= face_np[i].to_numpy()
    face_i_np_reshape=face_i_np.reshape(face_i_np.shape[1], 250, int(face_i_np.shape[0]/250))
    print(face_i_np_reshape.shape)

# %%
# Constants
frequencies = np.arange(0, 40, 2)  # 0 to 40 Hz
cycles = np.linspace(1, 10, len(frequencies))  # Variable cycles from 1 to 10
sampling_rate = 250
selected_columns = ['Fz', 'C3', 'Cz', 'C4', 'Pz', 'Po7', 'Oz', 'Po8']
# Assuming 'face_np' is the current class being processed
data = face_np  # Replace with 'scene_np' when processing the other class

# Initialize a dictionary to store power matrices for each channel
face_ERP = {channel: [] for channel in selected_columns}
scene_ERP = {channel: [] for channel in selected_columns}
Base_face={channel: [] for channel in selected_columns}

for channel_idx, channel_name in enumerate(selected_columns):
    blocks_erp_acticity = []
    blocks_erp_base=[]
    for i in range (len(face_np)): #12
        data_erp= face_np[i].to_numpy()
        data_erp_t=np.transpose(data_erp)
        data_erp_inst = data_erp_t[8, :]
        # Extract one channel
        data_i_erp_t = data_erp_t[channel_idx, :] # Trials are on the second dimension
        data_i_erp_inst=np.vstack((data_i_erp_t, data_erp_inst))
        # print(data_i_erp_inst.shape)
        mask = (data_i_erp_inst[1, :] == 'b') | (data_i_erp_inst[1, :] == 'g')
        
        base_i= data_i_erp_inst[:, mask]
        base_i_data= base_i[0, :]
        
        activity_i= data_i_erp_inst[:,~mask]
        activity_i_data= activity_i[0, :]
        # print(activity_i_data.shape[0])
        
        activity_i_downsample=activity_i_data.reshape(int(activity_i_data.shape[0]/250), 50,5)
        base_i_downsample=base_i_data.reshape(int(base_i_data.shape[0]/250), 50,5)
        
        activity_i_mean=activity_i_downsample.mean(axis=2)
        base_i_mean=base_i_downsample.mean(axis=2)
        
        block_acticity=activity_i_mean.mean(axis=0)
        block_base=base_i_mean.mean(axis=0)
        
        blocks_erp_acticity.append(block_acticity)
        blocks_erp_acticity_mean=np.mean(blocks_erp_acticity, axis=0)
        blocks_erp_base.append(block_base)
        blocks_erp_base_mean=np.mean(blocks_erp_base, axis=0)
        # print(len(blocks_erp_acticity_mean))
    face_ERP[channel_name].append(blocks_erp_acticity_mean)
    Base_face [channel_name].append(blocks_erp_base_mean)

# %%
# Constants
frequencies = np.arange(0, 40, 2)  # 0 to 40 Hz
cycles = np.linspace(1, 10, len(frequencies))  # Variable cycles from 1 to 10
sampling_rate = 250
selected_columns = ['Fz', 'C3', 'Cz', 'C4', 'Pz', 'Po7', 'Oz', 'Po8']
# Assuming 'face_np' is the current class being processed
data = face_np  # Replace with 'scene_np' when processing the other class

# Initialize a dictionary to store power matrices for each channel
scene_ERP = {channel: [] for channel in selected_columns}
Base_scene={channel: [] for channel in selected_columns}

for channel_idx, channel_name in enumerate(selected_columns):
    blocks_erp_acticity = []
    blocks_erp_base=[]
    for i in range (len(face_np)): #12
        data_erp= scene_np[i].to_numpy()
        data_erp_t=np.transpose(data_erp)
        data_erp_inst = data_erp_t[8, :]
        # Extract one channel
        data_i_erp_t = data_erp_t[channel_idx, :] # Trials are on the second dimension
        data_i_erp_inst=np.vstack((data_i_erp_t, data_erp_inst))
        # print(data_i_erp_inst.shape)
        mask = (data_i_erp_inst[1, :] == 'b') | (data_i_erp_inst[1, :] == 'g')
        
        base_i= data_i_erp_inst[:, mask]
        base_i_data= base_i[0, :]
        
        activity_i= data_i_erp_inst[:,~mask]
        activity_i_data= activity_i[0, :]
        # print(activity_i_data.shape[0])
        
        activity_i_downsample=activity_i_data.reshape(int(activity_i_data.shape[0]/250), 50,5)
        base_i_downsample=base_i_data.reshape(int(base_i_data.shape[0]/250), 50,5)
        
        activity_i_mean=activity_i_downsample.mean(axis=2)
        base_i_mean=base_i_downsample.mean(axis=2)
        
        block_acticity=activity_i_mean.mean(axis=0)
        block_base=base_i_mean.mean(axis=0)
        # print( block_acticity.shape, block_base.shape)
        blocks_erp_acticity.append(block_acticity)
        blocks_erp_acticity_mean=np.mean(blocks_erp_acticity, axis=0)
        blocks_erp_base.append(block_base)
        blocks_erp_base_mean=np.mean(blocks_erp_base, axis=0)
        # print(len(blocks_erp_acticity_mean))
    scene_ERP[channel_name].append(blocks_erp_acticity_mean)
    Base_scene [channel_name].append(blocks_erp_base_mean)

# %%
# Convert to NumPy array (values only)
array_face = np.array(list(face_ERP.values()))
squeezed_array_face = np.squeeze(array_face, axis=1).T
print(squeezed_array_face.shape)

# Convert to NumPy array (values only)
array_scene = np.array(list(scene_ERP.values()))
squeezed_array_scene = np.squeeze(array_scene, axis=1).T
print(squeezed_array_scene.shape)



# Convert the dictionary values to NumPy arrays
array1 = np.array(list(Base_face.values()))
array2 = np.array(list(Base_scene.values()))

# Calculate the element-wise average
average_array_base = (array1 + array2) / 2
average_array_base_squeeze=np.squeeze(average_array_base , axis=1).T

print(average_array_base_squeeze.shape)
# Out:
# (50, 8)
# (50, 8)
# (50, 8)

# %%
time_list = []
for n in range(50):
    time = (n*5)/(250)
    time_list.append(time)

# %%
plt.figure(figsize=(9,12))
plt.suptitle('Average Neural Response by Channel', y=1.002, fontsize=15, weight='bold') 

for channel in range(8):
    plt.subplot(5,2, channel + 1)  
    plt.plot(time_list, squeezed_array_face[:, channel], label=f'Scene', linewidth=2)
    plt.plot(time_list, squeezed_array_scene[:, channel], label=f'Face', linewidth=2)
    plt.plot(time_list, average_array_base_squeeze[:, channel], label=f'Base', linewidth=2)
    # plt.plot(time_list, base_mean[:, channel], label=f'Base', linewidth=1)
    plt.title(selected_columns[channel], fontsize=14, weight='bold')  # Adding the channel name as the title with bold and bigger font
    
    # Bigger and bold x and y axis labels
    plt.xlabel('Time (s)', fontsize=12, weight='bold')               
    plt.ylabel('Volt (µV)', fontsize=12, weight='bold')      

    # Bigger and bold x and y axis tick labels
    plt.xticks(fontsize=10, weight='bold')
    plt.yticks(fontsize=10, weight='bold')

    plt.legend(fontsize=10)

plt.tight_layout()
plt.show()

# %%
face_0_np= face_np[0].to_numpy()
face_0_np_t=np.transpose(face_0_np)
face_0_np_reshape=face_0_np_t.reshape(face_0_np_t.shape[0], 250, int(face_0_np_t.shape[1]/250))

# %%
face_0_np_reshape.shape
# Out:
# (9, 250, 37)

# %%
face_0_np= face_np[0].to_numpy()

# %%
face_np[0].shape
# Out:
# (9250, 9)

# %%
# Calculate the sampling interval
sampling_interval = 1 / 250  
times = np.arange(0, 1, step=sampling_interval)
times = times * 1000

# %%
import numpy as np
import pandas as pd

def morlet_wavelet(frequency, num_cycles, sampling_rate, duration=2):
    t = np.linspace(-duration/2, duration/2, int(sampling_rate * duration), endpoint=False)
    sine_wave = np.exp(2j * np.pi * frequency * t)
    amplitude_envelope = np.exp(-t**2 * (np.pi * frequency / num_cycles)**2)
    wavelet = sine_wave * amplitude_envelope
    return wavelet

def convolve_with_wavelet(data, wavelet):
    # Ensure data is in 2D form
    if data.ndim == 1:
        data = data[np.newaxis, :]
    n_signal = data.shape[1]
    n_wavelet = len(wavelet)
    n_convolution = n_signal + n_wavelet - 1

    data_fft = np.fft.fft(data, n_convolution, axis=1)
    wavelet_fft = np.fft.fft(wavelet, n_convolution)[np.newaxis, :]
    convolution_result_fft = data_fft * wavelet_fft
    convolution_result = np.fft.ifft(convolution_result_fft, axis=1)
    # Cut the data
    start = (n_wavelet - 1) // 2
    end = start + n_signal
    return convolution_result[:, start:end]

# %%
f_t=np.array(np.transpose(face_np[11]))
f_t_r=f_t
f_t.shape
# Out:
# (9, 10000)

# %%
def morlet_wavelet(frequency, num_cycles, sampling_rate, duration=2):
    t = np.linspace(-duration/2, duration/2, int(sampling_rate * duration), endpoint=False)
    sine_wave = np.exp(2j * np.pi * frequency * t)
    amplitude_envelope = np.exp(-t**2 * (np.pi * frequency / num_cycles)**2)
    wavelet = sine_wave * amplitude_envelope
    return wavelet

def convolve_with_wavelet(data, wavelet):
    # Ensure data is in 2D form
    if data.ndim == 1:
        data = data[np.newaxis, :]
    n_signal = data.shape[1]
    n_wavelet = len(wavelet)
    n_convolution = n_signal + n_wavelet - 1

    data_fft = np.fft.fft(data, n_convolution, axis=1)
    wavelet_fft = np.fft.fft(wavelet, n_convolution)[np.newaxis, :]
    convolution_result_fft = data_fft * wavelet_fft
    convolution_result = np.fft.ifft(convolution_result_fft, axis=1)
    # Cut the data
    start = (n_wavelet - 1) // 2
    end = start + n_signal
    return convolution_result[:, start:end]





# Constants
frequencies = np.arange(0, 40, 2)  # 0 to 40 Hz
cycles = np.linspace(1, 10, len(frequencies))  # Variable cycles from 1 to 10
sampling_rate = 250
selected_columns = ['Fz', 'C3', 'Cz', 'C4', 'Pz', 'Po7', 'Oz', 'Po8']
# Assuming 'face_np' is the current class being processed
data = face_np  # Replace with 'scene_np' when processing the other class

# Initialize a dictionary to store power matrices for each channel
face_power_matrices = {channel: [] for channel in selected_columns}
scene_power_matrices = {channel: [] for channel in selected_columns}

for channel_idx, channel_name in enumerate(selected_columns):
    face_power_matrix = []
    for freq, cycle in zip(frequencies, cycles):
        face_power_blocks_base_corrected=[]
        for i in range (len(face_np)): #12
            face_i_np= face_np[i].to_numpy()
            face_i_np_t=np.transpose(face_i_np)

            # Extract one channel
            data_i_face_t = face_i_np_t[channel_idx, :]  # Trials are on the second dimension
            data_i_face_inst = face_i_np_t[8, :]
            wavelet = morlet_wavelet(freq, cycle, sampling_rate)
            convolution = convolve_with_wavelet(data_i_face_t , wavelet)    
            power = np.abs(convolution)**2

            data_i_face_inst_2d = data_i_face_inst[np.newaxis, :]
            power_with_inst=np.concatenate([power,data_i_face_inst_2d], axis=0)
            power_with_inst_t=np.transpose(power_with_inst)
            mask = (power_with_inst_t[:, 1] == 'b') | (power_with_inst_t[:, 1] == 'g')
            base_l= power_with_inst_t[mask]
            base= base_l[:, :-1]
            print(base.shape)
            mean_base= np.mean(base_l[:, :-1], axis=0)
            print('mean_base', mean_base)
            
            epoch_size = 250
            epochs_base = []
            for start in range(0, len(base), epoch_size):
                end = start + epoch_size
                if end <= len(base):
                    epochs_base.append(base[start:end])
                else:
                    epochs_base.append(base[start])
                epochs_base_np=np.array(epochs_base)
            print('epochs_base_np.shape', epochs_base_np.shape)
            
            # Calculate the mean across the first dimension, excluding the last column
            mean_epochs_base = np.mean(epochs_base_np, axis=0)

            first_200 = mean_epochs_base[:200]
            mean_base_200=np.mean(first_200, axis=0)
            
            # print('mean_base',mean_base_200)
            last_50 = mean_epochs_base[200:]
            # print('last_50', last_50)
            
            # # print('base', base.shape, base)
            activity = power_with_inst_t[~mask]
            # print('activity ', activity.shape, activity )
            
            epoch_size = 250
            epochs = []
            for start in range(0, len(activity), epoch_size):
                end = start + epoch_size
                if end <= len(activity):
                    epochs.append(activity[start:end, :-1])
                else:
                    epochs.append(activity[start:,:-1])
                epochs_np=np.array(epochs)
            print(epochs_np.shape)
            
            # Calculate the mean across the first dimension, excluding the last column
            activity_mean_epochs = np.mean(epochs_np, axis=0)
            # print('activity_mean_epochs', activity_mean_epochs.shape) #activity_mean_epochs (250, 1)
            activity_mean_epochs_concat_base=np.concatenate([last_50,activity_mean_epochs], axis=0)
            print('activity_mean_epochs_concat_base', activity_mean_epochs_concat_base.shape) #activity_mean_epochs_concat_base (300, 1)
            
            baseline_corrected_activity=activity_mean_epochs_concat_base/mean_base_200
            print('baseline_corrected_activity', baseline_corrected_activity.shape) #baseline_corrected_activity (300, 1)
            
            face_power_blocks_base_corrected.append(baseline_corrected_activity)
            # power_blocks_base_corrected_np= np.array(power_blocks_base_corrected)
            # print('power_blocks_base_corrected_np', power_blocks_base_corrected_np.shape)     
        face_power_blocks_base_corrected_np_mean=np.mean(face_power_blocks_base_corrected, axis=0)
        print('power_blocks_base_corrected_np_mean', face_power_blocks_base_corrected_np_mean.shape)
        face_power_matrices[channel_name].append(face_power_blocks_base_corrected_np_mean)
        face_power_matrix.append(face_power_blocks_base_corrected_np_mean)
        face_power_matrix_np=np.array(face_power_matrix)
        print('face_power_matrix_np', face_power_matrix_np.shape)

# %%
# Constants
frequencies = np.arange(0, 40, 2)  # 0 to 40 Hz
cycles = np.linspace(1, 10, len(frequencies))  # Variable cycles from 1 to 10
sampling_rate = 250
selected_columns = ['Fz', 'C3', 'Cz', 'C4', 'Pz', 'Po7', 'Oz', 'Po8']
# Assuming 'face_np' is the current class being processed
data = face_np  # Replace with 'scene_np' when processing the other class

# Initialize a dictionary to store power matrices for each channel
scene_power_matrices = {channel: [] for channel in selected_columns}

for channel_idx, channel_name in enumerate(selected_columns):
    scene_power_matrix = []
    for freq, cycle in zip(frequencies, cycles):
        scene_power_blocks_base_corrected=[]
        for i in range (len(scene_np)): #12
            face_i_np= scene_np[i].to_numpy()
            face_i_np_t=np.transpose(face_i_np)

            # Extract one channel
            data_i_face_t = face_i_np_t[channel_idx, :]  # Trials are on the second dimension
            data_i_face_inst = face_i_np_t[8, :]
            wavelet = morlet_wavelet(freq, cycle, sampling_rate)
            convolution = convolve_with_wavelet(data_i_face_t , wavelet)    
            power = np.abs(convolution)**2

            data_i_face_inst_2d = data_i_face_inst[np.newaxis, :]
            power_with_inst=np.concatenate([power,data_i_face_inst_2d], axis=0)
            power_with_inst_t=np.transpose(power_with_inst)
            mask = (power_with_inst_t[:, 1] == 'b') | (power_with_inst_t[:, 1] == 'g')
            base_l= power_with_inst_t[mask]
            base= base_l[:, :-1]
            print(base.shape)
            mean_base= np.mean(base_l[:, :-1], axis=0)
            print('mean_base', mean_base)
            
            epoch_size = 250
            epochs_base = []
            for start in range(0, len(base), epoch_size):
                end = start + epoch_size
                if end <= len(base):
                    epochs_base.append(base[start:end])
                else:
                    epochs_base.append(base[start])
                epochs_base_np=np.array(epochs_base)
            print('epochs_base_np.shape', epochs_base_np.shape)
            
            # Calculate the mean across the first dimension, excluding the last column
            mean_epochs_base = np.mean(epochs_base_np, axis=0)

            first_200 = mean_epochs_base[:200]
            mean_base_200=np.mean(first_200, axis=0)
            
            # print('mean_base',mean_base_200)
            last_50 = mean_epochs_base[200:]
            # print('last_50', last_50)
            
            # # print('base', base.shape, base)
            activity = power_with_inst_t[~mask]
            # print('activity ', activity.shape, activity )
            
            epoch_size = 250
            epochs = []
            for start in range(0, len(activity), epoch_size):
                end = start + epoch_size
                if end <= len(activity):
                    epochs.append(activity[start:end, :-1])
                else:
                    epochs.append(activity[start:,:-1])
                epochs_np=np.array(epochs)
            print(epochs_np.shape)
            
            # Calculate the mean across the first dimension, excluding the last column
            activity_mean_epochs = np.mean(epochs_np, axis=0)
            # print('activity_mean_epochs', activity_mean_epochs.shape) #activity_mean_epochs (250, 1)
            activity_mean_epochs_concat_base=np.concatenate([last_50,activity_mean_epochs], axis=0)
            print('activity_mean_epochs_concat_base', activity_mean_epochs_concat_base.shape) #activity_mean_epochs_concat_base (300, 1)
            
            baseline_corrected_activity=activity_mean_epochs_concat_base/mean_base_200
            print('baseline_corrected_activity', baseline_corrected_activity.shape) #baseline_corrected_activity (300, 1)
            
            scene_power_blocks_base_corrected.append(baseline_corrected_activity)
            # power_blocks_base_corrected_np= np.array(power_blocks_base_corrected)
            # print('power_blocks_base_corrected_np', power_blocks_base_corrected_np.shape)     
        scene_power_blocks_base_corrected_np_mean=np.mean(scene_power_blocks_base_corrected, axis=0)
        print('power_blocks_base_corrected_np_mean', scene_power_blocks_base_corrected_np_mean.shape)
        scene_power_matrices[channel_name].append(scene_power_blocks_base_corrected_np_mean)
        scene_power_matrix.append(scene_power_blocks_base_corrected_np_mean)
        scene_power_matrix_np=np.array(scene_power_matrix)
        print('scene_power_matrix_np', scene_power_matrix_np.shape)
# Out:
# (1250, 1)
# mean_base [138128.86894394393]
# epochs_base_np.shape (5, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [329759.5983610885]
# epochs_base_np.shape (6, 250, 1)
# (28, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [143468.54619065623]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [1159564.6280456171]
# epochs_base_np.shape (4, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (500, 1)
# mean_base [189666.79764874457]
# epochs_base_np.shape (2, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [129831.73838845598]
# epochs_base_np.shape (5, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [96866.36304273692]
# epochs_base_np.shape (6, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (750, 1)
# mean_base [444522.6610588883]
# epochs_base_np.shape (3, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [260681.88868387754]
# epochs_base_np.shape (4, 250, 1)
# (39, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [1052076.265811873]
# epochs_base_np.shape (6, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [478777.327194894]
# epochs_base_np.shape (5, 250, 1)
# (26, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [1087116.7587127478]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# scene_power_matrix_np (1, 300, 1)
# (1250, 1)
# mean_base [73933.70503732408]
# epochs_base_np.shape (5, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [112052.39575176853]
# epochs_base_np.shape (6, 250, 1)
# (28, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [92818.72573320821]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [111222.85421942364]
# epochs_base_np.shape (4, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (500, 1)
# mean_base [73981.77278548117]
# epochs_base_np.shape (2, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [137658.06265536472]
# epochs_base_np.shape (5, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [78081.73800718125]
# epochs_base_np.shape (6, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (750, 1)
# mean_base [134086.26005923405]
# epochs_base_np.shape (3, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [163399.96285100322]
# epochs_base_np.shape (4, 250, 1)
# (39, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [135973.38331582028]
# epochs_base_np.shape (6, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [92249.34384257118]
# epochs_base_np.shape (5, 250, 1)
# (26, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [181770.47245152766]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# scene_power_matrix_np (2, 300, 1)
# (1250, 1)
# mean_base [13225.07043590194]
# epochs_base_np.shape (5, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [25108.635459780962]
# epochs_base_np.shape (6, 250, 1)
# (28, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [17172.424723982913]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [18701.688671108437]
# epochs_base_np.shape (4, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (500, 1)
# mean_base [23542.523184098263]
# epochs_base_np.shape (2, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [29340.66963423236]
# epochs_base_np.shape (5, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [14557.031658308471]
# epochs_base_np.shape (6, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (750, 1)
# mean_base [47334.237767189654]
# epochs_base_np.shape (3, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [33441.310554174604]
# epochs_base_np.shape (4, 250, 1)
# (39, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [16418.59953637641]
# epochs_base_np.shape (6, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [19531.995143956912]
# epochs_base_np.shape (5, 250, 1)
# (26, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [24088.77558201005]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# scene_power_matrix_np (3, 300, 1)
# (1250, 1)
# mean_base [7358.412327907324]
# epochs_base_np.shape (5, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [13340.199783861754]
# epochs_base_np.shape (6, 250, 1)
# (28, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [10294.67161625649]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [11726.625340427547]
# epochs_base_np.shape (4, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (500, 1)
# mean_base [8437.524067856793]
# epochs_base_np.shape (2, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [10285.764562635195]
# epochs_base_np.shape (5, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [11299.430979262175]
# epochs_base_np.shape (6, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (750, 1)
# mean_base [16322.589207716594]
# epochs_base_np.shape (3, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [17107.354130233267]
# epochs_base_np.shape (4, 250, 1)
# (39, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [8713.067944041753]
# epochs_base_np.shape (6, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [14427.268804824454]
# epochs_base_np.shape (5, 250, 1)
# (26, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [8493.302862344444]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# scene_power_matrix_np (4, 300, 1)
# (1250, 1)
# mean_base [7862.835752495612]
# epochs_base_np.shape (5, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [9213.626885451]
# epochs_base_np.shape (6, 250, 1)
# (28, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [8114.666552337615]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [14128.959720469597]
# epochs_base_np.shape (4, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (500, 1)
# mean_base [7036.851359948339]
# epochs_base_np.shape (2, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [9556.513835419406]
# epochs_base_np.shape (5, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [11289.45523643032]
# epochs_base_np.shape (6, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (750, 1)
# mean_base [9797.711025425262]
# epochs_base_np.shape (3, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [11694.893552245718]
# epochs_base_np.shape (4, 250, 1)
# (39, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [9629.21530647844]
# epochs_base_np.shape (6, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [11088.720149009825]
# epochs_base_np.shape (5, 250, 1)
# (26, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [8513.743528805448]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# scene_power_matrix_np (5, 300, 1)
# (1250, 1)
# mean_base [9083.103663005711]
# epochs_base_np.shape (5, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [8736.387062746257]
# epochs_base_np.shape (6, 250, 1)
# (28, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [17212.092156653685]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [12076.467118317212]
# epochs_base_np.shape (4, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (500, 1)
# mean_base [7516.749373129412]
# epochs_base_np.shape (2, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [12279.80019186878]
# epochs_base_np.shape (5, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [14906.170582995574]
# epochs_base_np.shape (6, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (750, 1)
# mean_base [12301.752790875733]
# epochs_base_np.shape (3, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [12223.676037165082]
# epochs_base_np.shape (4, 250, 1)
# (39, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [15889.191143956483]
# epochs_base_np.shape (6, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [10497.239957848]
# epochs_base_np.shape (5, 250, 1)
# (26, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [14379.65896312877]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# scene_power_matrix_np (6, 300, 1)
# (1250, 1)
# mean_base [9756.350834392122]
# epochs_base_np.shape (5, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [8053.314290060702]
# epochs_base_np.shape (6, 250, 1)
# (28, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [19416.51239768802]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [10262.511601789107]
# epochs_base_np.shape (4, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (500, 1)
# mean_base [6427.341736369531]
# epochs_base_np.shape (2, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [14769.8167501392]
# epochs_base_np.shape (5, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [11685.581373414285]
# epochs_base_np.shape (6, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (750, 1)
# mean_base [12584.92871390024]
# epochs_base_np.shape (3, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [13391.86241566881]
# epochs_base_np.shape (4, 250, 1)
# (39, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [15312.587057200268]
# epochs_base_np.shape (6, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [9146.513918696615]
# epochs_base_np.shape (5, 250, 1)
# (26, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [15718.51947855689]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# scene_power_matrix_np (7, 300, 1)
# (1250, 1)
# mean_base [5379.351738362316]
# epochs_base_np.shape (5, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [4637.354849583535]
# epochs_base_np.shape (6, 250, 1)
# (28, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [8600.460902109942]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [6110.878519440144]
# epochs_base_np.shape (4, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (500, 1)
# mean_base [3324.6929181849528]
# epochs_base_np.shape (2, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [8590.679595139776]
# epochs_base_np.shape (5, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [5185.9260749228815]
# epochs_base_np.shape (6, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (750, 1)
# mean_base [7305.453996485507]
# epochs_base_np.shape (3, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [7172.991534600982]
# epochs_base_np.shape (4, 250, 1)
# (39, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [6442.202502567474]
# epochs_base_np.shape (6, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [4410.96813766912]
# epochs_base_np.shape (5, 250, 1)
# (26, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [7676.173277597482]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# scene_power_matrix_np (8, 300, 1)
# (1250, 1)
# mean_base [2195.693153113279]
# epochs_base_np.shape (5, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [2563.543057386441]
# epochs_base_np.shape (6, 250, 1)
# (28, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [2474.418188335247]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [2658.9883866654104]
# epochs_base_np.shape (4, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (500, 1)
# mean_base [2001.1032779009893]
# epochs_base_np.shape (2, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [3210.8444848586482]
# epochs_base_np.shape (5, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [1910.928958430907]
# epochs_base_np.shape (6, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (750, 1)
# mean_base [2845.286853607102]
# epochs_base_np.shape (3, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [2375.9290362051643]
# epochs_base_np.shape (4, 250, 1)
# (39, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [2225.6902403387357]
# epochs_base_np.shape (6, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [2054.993412312311]
# epochs_base_np.shape (5, 250, 1)
# (26, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [2580.6051871334903]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# scene_power_matrix_np (9, 300, 1)
# (1250, 1)
# mean_base [961.1014304337746]
# epochs_base_np.shape (5, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [1447.8444654471139]
# epochs_base_np.shape (6, 250, 1)
# (28, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [964.5542713922567]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [1125.4998375750395]
# epochs_base_np.shape (4, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (500, 1)
# mean_base [1579.015973606896]
# epochs_base_np.shape (2, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [1110.0415038079695]
# epochs_base_np.shape (5, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [794.0366197146551]
# epochs_base_np.shape (6, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (750, 1)
# mean_base [1483.323053459626]
# epochs_base_np.shape (3, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [858.6400076646189]
# epochs_base_np.shape (4, 250, 1)
# (39, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [1077.9023601712145]
# epochs_base_np.shape (6, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [1238.9809905235927]
# epochs_base_np.shape (5, 250, 1)
# (26, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [910.369804197829]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# scene_power_matrix_np (10, 300, 1)
# (1250, 1)
# mean_base [434.8740285765311]
# epochs_base_np.shape (5, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [717.2142724226867]
# epochs_base_np.shape (6, 250, 1)
# (28, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [532.3837332391163]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [440.5398673630465]
# epochs_base_np.shape (4, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (500, 1)
# mean_base [713.4732539576071]
# epochs_base_np.shape (2, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [376.87494123275]
# epochs_base_np.shape (5, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [397.8997373333921]
# epochs_base_np.shape (6, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (750, 1)
# mean_base [673.6989533548885]
# epochs_base_np.shape (3, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [360.8411694889471]
# epochs_base_np.shape (4, 250, 1)
# (39, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [502.1931592718747]
# epochs_base_np.shape (6, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [582.4042318604203]
# epochs_base_np.shape (5, 250, 1)
# (26, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [341.247091904378]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# scene_power_matrix_np (11, 300, 1)
# (1250, 1)
# mean_base [198.72592961248142]
# epochs_base_np.shape (5, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [264.4067780494155]
# epochs_base_np.shape (6, 250, 1)
# (28, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [229.4720860162688]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [183.68580726224062]
# epochs_base_np.shape (4, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (500, 1)
# mean_base [238.95453115195082]
# epochs_base_np.shape (2, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [111.268093127133]
# epochs_base_np.shape (5, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [189.7279283876369]
# epochs_base_np.shape (6, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (750, 1)
# mean_base [218.97163052189046]
# epochs_base_np.shape (3, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [157.25597303967254]
# epochs_base_np.shape (4, 250, 1)
# (39, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [202.13428280404256]
# epochs_base_np.shape (6, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [188.94833769485456]
# epochs_base_np.shape (5, 250, 1)
# (26, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [143.0337148582601]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# scene_power_matrix_np (12, 300, 1)
# (1250, 1)
# mean_base [72.0391723474127]
# epochs_base_np.shape (5, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [78.74749322952262]
# epochs_base_np.shape (6, 250, 1)
# (28, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [62.66003024935667]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [82.69721059647689]
# epochs_base_np.shape (4, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (500, 1)
# mean_base [70.4664555096288]
# epochs_base_np.shape (2, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [37.48054211324653]
# epochs_base_np.shape (5, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [70.77313590155782]
# epochs_base_np.shape (6, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (750, 1)
# mean_base [83.18991243704887]
# epochs_base_np.shape (3, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [55.39528781836106]
# epochs_base_np.shape (4, 250, 1)
# (39, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [64.28858893940057]
# epochs_base_np.shape (6, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [50.47009177046287]
# epochs_base_np.shape (5, 250, 1)
# (26, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [59.4343450385486]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# scene_power_matrix_np (13, 300, 1)
# (1250, 1)
# mean_base [41.126072578583056]
# epochs_base_np.shape (5, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [45.90255018485913]
# epochs_base_np.shape (6, 250, 1)
# (28, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [31.65605252688714]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [44.70541222298515]
# epochs_base_np.shape (4, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (500, 1)
# mean_base [50.65050849320294]
# epochs_base_np.shape (2, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [28.17676692923923]
# epochs_base_np.shape (5, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [32.92992924746029]
# epochs_base_np.shape (6, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (750, 1)
# mean_base [44.45293555912821]
# epochs_base_np.shape (3, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [25.682064654642332]
# epochs_base_np.shape (4, 250, 1)
# (39, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [31.20350501054084]
# epochs_base_np.shape (6, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [28.106671857581173]
# epochs_base_np.shape (5, 250, 1)
# (26, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [33.54257616148956]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# scene_power_matrix_np (14, 300, 1)
# (1250, 1)
# mean_base [58.676469290720625]
# epochs_base_np.shape (5, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [78.97539773774795]
# epochs_base_np.shape (6, 250, 1)
# (28, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [50.41460845790921]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [45.60055689494986]
# epochs_base_np.shape (4, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (500, 1)
# mean_base [105.2752713700184]
# epochs_base_np.shape (2, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [41.038894367822095]
# epochs_base_np.shape (5, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [33.27167514038786]
# epochs_base_np.shape (6, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (750, 1)
# mean_base [47.75828253839167]
# epochs_base_np.shape (3, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [41.20581339335495]
# epochs_base_np.shape (4, 250, 1)
# (39, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [48.05213540711677]
# epochs_base_np.shape (6, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [39.30592886373122]
# epochs_base_np.shape (5, 250, 1)
# (26, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [42.26629367849301]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# scene_power_matrix_np (15, 300, 1)
# (1250, 1)
# mean_base [80.83495860666491]
# epochs_base_np.shape (5, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [115.53075607522783]
# epochs_base_np.shape (6, 250, 1)
# (28, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [85.19874366400187]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [69.74610570872215]
# epochs_base_np.shape (4, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (500, 1)
# mean_base [130.3902295302217]
# epochs_base_np.shape (2, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [67.43498518200242]
# epochs_base_np.shape (5, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [49.04424459276251]
# epochs_base_np.shape (6, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (750, 1)
# mean_base [66.46610697402666]
# epochs_base_np.shape (3, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [57.8251354263092]
# epochs_base_np.shape (4, 250, 1)
# (39, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [75.74542993276108]
# epochs_base_np.shape (6, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [52.69641886318843]
# epochs_base_np.shape (5, 250, 1)
# (26, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [62.35773003238773]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# scene_power_matrix_np (16, 300, 1)
# (1250, 1)
# mean_base [90.79785725867602]
# epochs_base_np.shape (5, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [135.45009226368197]
# epochs_base_np.shape (6, 250, 1)
# (28, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [117.80933798803251]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [92.10331532130887]
# epochs_base_np.shape (4, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (500, 1)
# mean_base [95.256945237006]
# epochs_base_np.shape (2, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [101.32553316115913]
# epochs_base_np.shape (5, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [79.27473211805716]
# epochs_base_np.shape (6, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (750, 1)
# mean_base [84.12171906063324]
# epochs_base_np.shape (3, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [51.32945045363443]
# epochs_base_np.shape (4, 250, 1)
# (39, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [95.36298563700872]
# epochs_base_np.shape (6, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [69.93909438221372]
# epochs_base_np.shape (5, 250, 1)
# (26, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [71.36730941535855]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# scene_power_matrix_np (17, 300, 1)
# (1250, 1)
# mean_base [88.87329788818282]
# epochs_base_np.shape (5, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [144.9578941407586]
# epochs_base_np.shape (6, 250, 1)
# (28, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [109.43002176147834]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [105.6342853100085]
# epochs_base_np.shape (4, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (500, 1)
# mean_base [77.66307863247714]
# epochs_base_np.shape (2, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [106.06127630258561]
# epochs_base_np.shape (5, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [85.88034069167854]
# epochs_base_np.shape (6, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (750, 1)
# mean_base [86.7620689502841]
# epochs_base_np.shape (3, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [43.433676304951]
# epochs_base_np.shape (4, 250, 1)
# (39, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [95.46712086853502]
# epochs_base_np.shape (6, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [70.0874076891526]
# epochs_base_np.shape (5, 250, 1)
# (26, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [64.39784255642984]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# scene_power_matrix_np (18, 300, 1)
# (1250, 1)
# mean_base [79.04434475208939]
# epochs_base_np.shape (5, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [114.8463914366124]
# epochs_base_np.shape (6, 250, 1)
# (28, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [85.6741337757517]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [98.9622044880212]
# epochs_base_np.shape (4, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (500, 1)
# mean_base [82.50921280460105]
# epochs_base_np.shape (2, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [73.64142806022335]
# epochs_base_np.shape (5, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [63.24289963017131]
# epochs_base_np.shape (6, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (750, 1)
# mean_base [74.0654730619909]
# epochs_base_np.shape (3, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [37.45697681729521]
# epochs_base_np.shape (4, 250, 1)
# (39, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [73.88000671995407]
# epochs_base_np.shape (6, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [46.38346182906868]
# epochs_base_np.shape (5, 250, 1)
# (26, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [51.597356810472014]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# scene_power_matrix_np (19, 300, 1)
# (1250, 1)
# mean_base [53.23152295009268]
# epochs_base_np.shape (5, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [68.02582731170612]
# epochs_base_np.shape (6, 250, 1)
# (28, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [67.45416281838666]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [67.4743171740437]
# epochs_base_np.shape (4, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (500, 1)
# mean_base [78.91333066202021]
# epochs_base_np.shape (2, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [46.90179849793085]
# epochs_base_np.shape (5, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [36.63646539131783]
# epochs_base_np.shape (6, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (750, 1)
# mean_base [55.18251185001951]
# epochs_base_np.shape (3, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [24.559649824347808]
# epochs_base_np.shape (4, 250, 1)
# (39, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [51.594689189123734]
# epochs_base_np.shape (6, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [25.828787438691563]
# epochs_base_np.shape (5, 250, 1)
# (26, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [40.25150116812513]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# scene_power_matrix_np (20, 300, 1)
# (1250, 1)
# mean_base [82759.68838278999]
# epochs_base_np.shape (5, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [841171.9146670081]
# epochs_base_np.shape (6, 250, 1)
# (28, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [194154.32982553428]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [1010140.1095294604]
# epochs_base_np.shape (4, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (500, 1)
# mean_base [115898.22497562463]
# epochs_base_np.shape (2, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [213255.51054617346]
# epochs_base_np.shape (5, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [219765.74084613883]
# epochs_base_np.shape (6, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (750, 1)
# mean_base [679012.2270308228]
# epochs_base_np.shape (3, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [150080.5516599352]
# epochs_base_np.shape (4, 250, 1)
# (39, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [660800.4096388331]
# epochs_base_np.shape (6, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [947593.7873998415]
# epochs_base_np.shape (5, 250, 1)
# (26, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [2285826.8985907948]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# scene_power_matrix_np (1, 300, 1)
# (1250, 1)
# mean_base [236100.83708430247]
# epochs_base_np.shape (5, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [275586.71060956304]
# epochs_base_np.shape (6, 250, 1)
# (28, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [189823.3108433229]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [182791.13341909516]
# epochs_base_np.shape (4, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (500, 1)
# mean_base [286926.0315079777]
# epochs_base_np.shape (2, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [302281.33047865133]
# epochs_base_np.shape (5, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [323186.1944896995]
# epochs_base_np.shape (6, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (750, 1)
# mean_base [441666.36206407356]
# epochs_base_np.shape (3, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [299963.51870005863]
# epochs_base_np.shape (4, 250, 1)
# (39, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [244841.2678159375]
# epochs_base_np.shape (6, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [147768.90928178412]
# epochs_base_np.shape (5, 250, 1)
# (26, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [93382.82693260866]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# scene_power_matrix_np (2, 300, 1)
# (1250, 1)
# mean_base [41742.74919968493]
# epochs_base_np.shape (5, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [41269.92985434116]
# epochs_base_np.shape (6, 250, 1)
# (28, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [31384.951808675323]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [28037.3828918016]
# epochs_base_np.shape (4, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (500, 1)
# mean_base [37905.64288301634]
# epochs_base_np.shape (2, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [42744.09185997337]
# epochs_base_np.shape (5, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [29620.055771934163]
# epochs_base_np.shape (6, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (750, 1)
# mean_base [68143.8276554731]
# epochs_base_np.shape (3, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [32302.08490235957]
# epochs_base_np.shape (4, 250, 1)
# (39, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [37132.45166187404]
# epochs_base_np.shape (6, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [26215.042151693877]
# epochs_base_np.shape (5, 250, 1)
# (26, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [25926.547627390766]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# scene_power_matrix_np (3, 300, 1)
# (1250, 1)
# mean_base [13191.647859441871]
# epochs_base_np.shape (5, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [17086.932663553234]
# epochs_base_np.shape (6, 250, 1)
# (28, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [13401.012921684014]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [9243.308675030908]
# epochs_base_np.shape (4, 250, 1)
# (36, 250, 1)
# ...
# (1000, 1)
# mean_base [68.86915892182216]
# epochs_base_np.shape (4, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (500, 1)
# mean_base [55.9898068298685]
# epochs_base_np.shape (2, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [48.04795672229437]
# epochs_base_np.shape (5, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [35.52353771264843]
# epochs_base_np.shape (6, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (750, 1)
# mean_base [70.60647155370725]
# epochs_base_np.shape (3, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [39.152915224072004]
# epochs_base_np.shape (4, 250, 1)
# (39, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [35.83756837351108]
# epochs_base_np.shape (6, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [123.32461662234692]
# epochs_base_np.shape (5, 250, 1)
# (26, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [89.69473975033243]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# scene_power_matrix_np (13, 300, 1)
# (1250, 1)
# mean_base [42.846710586241635]
# epochs_base_np.shape (5, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [34.58792681333121]
# epochs_base_np.shape (6, 250, 1)
# (28, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [34.42684757415662]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [44.86699786156041]
# epochs_base_np.shape (4, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (500, 1)
# mean_base [59.935480014738104]
# epochs_base_np.shape (2, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [28.557293716462212]
# epochs_base_np.shape (5, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [22.163354843390223]
# epochs_base_np.shape (6, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (750, 1)
# mean_base [33.415880457273694]
# epochs_base_np.shape (3, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [27.426182981204306]
# epochs_base_np.shape (4, 250, 1)
# (39, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [26.775482825805398]
# epochs_base_np.shape (6, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [98.13030234920755]
# epochs_base_np.shape (5, 250, 1)
# (26, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [54.84661972489784]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# scene_power_matrix_np (14, 300, 1)
# (1250, 1)
# mean_base [78.4189413979707]
# epochs_base_np.shape (5, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [64.08956518173983]
# epochs_base_np.shape (6, 250, 1)
# (28, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [48.26645648410957]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [49.52579683731472]
# epochs_base_np.shape (4, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (500, 1)
# mean_base [102.98922470293806]
# epochs_base_np.shape (2, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [39.29113685192913]
# epochs_base_np.shape (5, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [33.326202007745856]
# epochs_base_np.shape (6, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (750, 1)
# mean_base [42.938922827284834]
# epochs_base_np.shape (3, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [41.01252502415949]
# epochs_base_np.shape (4, 250, 1)
# (39, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [49.50908081710635]
# epochs_base_np.shape (6, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [91.90788922292974]
# epochs_base_np.shape (5, 250, 1)
# (26, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [52.32274953432696]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# scene_power_matrix_np (15, 300, 1)
# (1250, 1)
# mean_base [97.22840278106202]
# epochs_base_np.shape (5, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [99.70882474699943]
# epochs_base_np.shape (6, 250, 1)
# (28, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [72.00013868699023]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [65.98457580784115]
# epochs_base_np.shape (4, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (500, 1)
# mean_base [121.21035783947237]
# epochs_base_np.shape (2, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [68.58299579587705]
# epochs_base_np.shape (5, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [56.435299452209634]
# epochs_base_np.shape (6, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (750, 1)
# mean_base [62.73296486127515]
# epochs_base_np.shape (3, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [54.92332957190317]
# epochs_base_np.shape (4, 250, 1)
# (39, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [67.17233258721569]
# epochs_base_np.shape (6, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [91.32056329091634]
# epochs_base_np.shape (5, 250, 1)
# (26, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [54.67569927646825]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# scene_power_matrix_np (16, 300, 1)
# (1250, 1)
# mean_base [85.26778883123418]
# epochs_base_np.shape (5, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [127.37084827632967]
# epochs_base_np.shape (6, 250, 1)
# (28, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [96.4716709151083]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [75.12798743061572]
# epochs_base_np.shape (4, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (500, 1)
# mean_base [94.06377298083218]
# epochs_base_np.shape (2, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [106.43096114509106]
# epochs_base_np.shape (5, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [77.30234697701783]
# epochs_base_np.shape (6, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (750, 1)
# mean_base [67.15869839187951]
# epochs_base_np.shape (3, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [53.88505216459972]
# epochs_base_np.shape (4, 250, 1)
# (39, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [79.74123691990455]
# epochs_base_np.shape (6, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [101.87974372145773]
# epochs_base_np.shape (5, 250, 1)
# (26, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [51.950055209780814]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# scene_power_matrix_np (17, 300, 1)
# (1250, 1)
# mean_base [74.36124005761471]
# epochs_base_np.shape (5, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [135.03558874984736]
# epochs_base_np.shape (6, 250, 1)
# (28, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [98.20975035295609]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [73.08269397451564]
# epochs_base_np.shape (4, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (500, 1)
# mean_base [71.69106213203113]
# epochs_base_np.shape (2, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [120.66280353311754]
# epochs_base_np.shape (5, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [76.51886800138328]
# epochs_base_np.shape (6, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (750, 1)
# mean_base [65.9029433749065]
# epochs_base_np.shape (3, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [49.195466195011335]
# epochs_base_np.shape (4, 250, 1)
# (39, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [87.66392291734496]
# epochs_base_np.shape (6, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [105.63145334089704]
# epochs_base_np.shape (5, 250, 1)
# (26, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [50.85190335546785]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# scene_power_matrix_np (18, 300, 1)
# (1250, 1)
# mean_base [75.62012984292583]
# epochs_base_np.shape (5, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [102.50150973478773]
# epochs_base_np.shape (6, 250, 1)
# (28, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [84.15494464256416]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [54.23393403945644]
# epochs_base_np.shape (4, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (500, 1)
# mean_base [53.73747928660038]
# epochs_base_np.shape (2, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [85.97283465801158]
# epochs_base_np.shape (5, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [58.66448118863385]
# epochs_base_np.shape (6, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (750, 1)
# mean_base [55.635688862619155]
# epochs_base_np.shape (3, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [39.1824446804676]
# epochs_base_np.shape (4, 250, 1)
# (39, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [67.5923973965191]
# epochs_base_np.shape (6, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [88.04465618751242]
# epochs_base_np.shape (5, 250, 1)
# (26, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [47.43474020979935]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# scene_power_matrix_np (19, 300, 1)
# (1250, 1)
# mean_base [57.35678488102653]
# epochs_base_np.shape (5, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [55.45782698469322]
# epochs_base_np.shape (6, 250, 1)
# (28, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [63.39524797508245]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [31.557990602253867]
# epochs_base_np.shape (4, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (500, 1)
# mean_base [39.298461979161196]
# epochs_base_np.shape (2, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [48.55714254587686]
# epochs_base_np.shape (5, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [35.566506122151985]
# epochs_base_np.shape (6, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (750, 1)
# mean_base [43.293298474891074]
# epochs_base_np.shape (3, 250, 1)
# (38, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [25.27930539605886]
# epochs_base_np.shape (4, 250, 1)
# (39, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [42.72808069745456]
# epochs_base_np.shape (6, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [64.7127986430144]
# epochs_base_np.shape (5, 250, 1)
# (26, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [45.40336663115304]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# scene_power_matrix_np (20, 300, 1)

# %%
power_matrices['Fz'][0].shape
# Out:
# (300, 1)

# %%
import numpy as np
import pandas as pd

for channel, power_data in face_power_matrices.items():
    # Convert the list of arrays into a 2D array
    power_matrix = np.concatenate(power_data, axis=1)  # Concatenate along the second axis

    # Convert to DataFrame
    df = pd.DataFrame(power_matrix)

    # Save to CSV
    df.to_csv(f'face_power_matrix_{channel}.csv', index=False)

# %%
for channel, power_data in scene_power_matrices.items():
    # Convert the list of arrays into a 2D array
    power_matrix = np.concatenate(power_data, axis=1)  # Concatenate along the second axis

    # Convert to DataFrame
    df = pd.DataFrame(power_matrix)

    # Save to CSV
    df.to_csv(f'scene_power_matrix_{channel}.csv', index=False)

# %%
def plot_time_frequency(data, title, ax):
    # Use the provided axes object for plotting
    data_to_plot = 10 * np.log10(data.T + 1e-6)  # Transpose and Log transform of power; add a small constant to avoid log(0)
    img = ax.imshow(data_to_plot, aspect='auto', cmap='jet', origin='lower',
                    extent=[times[0], times[-1], frequencies[0], frequencies[-1]], vmin=-2, vmax=2)
    fig.colorbar(img, ax=ax, format='%+2.0f dB')  # Use fig.colorbar to specify the axes
    ax.set_xlabel('Time (ms)')
    ax.set_ylabel('Frequency (Hz)')
    ax.set_title(title)


n_channels = 8
fig, axs = plt.subplots(n_channels, 2, figsize=(10, 20))  # Adjust figsize as needed

for i, channel in enumerate(selected_columns):
    # Load from CSV
    df_face = pd.read_csv(f'face_power_matrix_{channel}.csv')
    df_scene = pd.read_csv(f'scene_power_matrix_{channel}.csv')

    # Convert DataFrame to numpy array
    face_power_matrix = df_face.to_numpy()
    scene_power_matrix = df_scene.to_numpy()

    # Use the data from the 50th sample point to 300th
    face_power_matrix_reduced = face_power_matrix[50:300, :]
    scene_power_matrix_reduced = scene_power_matrix[50:300, :]

    # Plot the results for face and scene
    plot_time_frequency(face_power_matrix_reduced, f'Face Power - {channel}', axs[i, 0])
    plot_time_frequency(scene_power_matrix_reduced, f'Scene Power - {channel}', axs[i, 1])

plt.tight_layout()
plt.show()

# %%
# Load and plot for each channel
for channel in selected_columns:
    # Load from CSV
    df = pd.read_csv(f'scene_power_matrix_{channel}.csv')

    # Convert DataFrame to numpy array
    power_matrix = df.to_numpy()

    # Use the data from the 50th sample point to 300th
    power_matrix_reduced = power_matrix[50:300, :]

    # Plot the results
    plot_time_frequency(power_matrix_reduced, f'Power Matrix - {channel}')

# %%
# Constants
frequencies = np.arange(0, 40, 2)  # 0 to 40 Hz
cycles = np.linspace(1, 10, len(frequencies))  # Variable cycles from 1 to 10
sampling_rate = 250
selected_columns = ['Fz', 'C3', 'Cz', 'C4', 'Pz', 'Po7', 'Oz', 'Po8']

power_matrix = []
for freq, cycle in zip(frequencies, cycles):
    power_blocks_base_corrected=[]
    for i in range (len(face_np)): #12
        face_i_np= face_np[i].to_numpy()
        face_i_np_t=np.transpose(face_i_np)

        # Extract one channel
        data_i_face_t = face_i_np_t[0, :]  # Trials are on the second dimension
        data_i_face_inst = face_i_np_t[8, :]
        wavelet = morlet_wavelet(freq, cycle, sampling_rate)
        convolution = convolve_with_wavelet(data_i_face_t , wavelet)    
        power = np.abs(convolution)**2

        data_i_face_inst_2d = data_i_face_inst[np.newaxis, :]
        power_with_inst=np.concatenate([power,data_i_face_inst_2d], axis=0)
        power_with_inst_t=np.transpose(power_with_inst)
        mask = (power_with_inst_t[:, 1] == 'b') | (power_with_inst_t[:, 1] == 'g')
        base_l= power_with_inst_t[mask]
        base= base_l[:, :-1]
        print(base.shape)
        mean_base= np.mean(base_l[:, :-1], axis=0)
        print('mean_base', mean_base)
        
        epoch_size = 250
        epochs_base = []
        for start in range(0, len(base), epoch_size):
            end = start + epoch_size
            if end <= len(base):
                epochs_base.append(base[start:end])
            else:
                epochs_base.append(base[start])
            epochs_base_np=np.array(epochs_base)
        print('epochs_base_np.shape', epochs_base_np.shape)
        
        # Calculate the mean across the first dimension, excluding the last column
        mean_epochs_base = np.mean(epochs_base_np, axis=0)

        first_200 = mean_epochs_base[:200]
        mean_base_200=np.mean(first_200, axis=0)
        
        # print('mean_base',mean_base_200)
        last_50 = mean_epochs_base[200:]
        # print('last_50', last_50)
        
        # # print('base', base.shape, base)
        activity = power_with_inst_t[~mask]
        # print('activity ', activity.shape, activity )
        
        epoch_size = 250
        epochs = []
        for start in range(0, len(activity), epoch_size):
            end = start + epoch_size
            if end <= len(activity):
                epochs.append(activity[start:end, :-1])
            else:
                epochs.append(activity[start:,:-1])
            epochs_np=np.array(epochs)
        print(epochs_np.shape)
        
        # Calculate the mean across the first dimension, excluding the last column
        activity_mean_epochs = np.mean(epochs_np, axis=0)
        # print('activity_mean_epochs', activity_mean_epochs.shape) #activity_mean_epochs (250, 1)
        activity_mean_epochs_concat_base=np.concatenate([last_50,activity_mean_epochs], axis=0)
        print('activity_mean_epochs_concat_base', activity_mean_epochs_concat_base.shape) #activity_mean_epochs_concat_base (300, 1)
        
        baseline_corrected_activity=activity_mean_epochs_concat_base/mean_base_200
        print('baseline_corrected_activity', baseline_corrected_activity.shape) #baseline_corrected_activity (300, 1)
        
        power_blocks_base_corrected.append(baseline_corrected_activity)
        # power_blocks_base_corrected_np= np.array(power_blocks_base_corrected)
        # print('power_blocks_base_corrected_np', power_blocks_base_corrected_np.shape)     
    power_blocks_base_corrected_np_mean=np.mean(power_blocks_base_corrected, axis=0)
    print('power_blocks_base_corrected_np_mean', power_blocks_base_corrected_np_mean.shape)
    power_matrix.append(power_blocks_base_corrected_np_mean)
    power_matrix_np=np.array(power_matrix)
    print('power_matrix_np', power_matrix_np.shape)
# Out:
# (1000, 1)
# mean_base [932720.6502288993]
# epochs_base_np.shape (4, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [169258.63847681318]
# epochs_base_np.shape (6, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [307359.8654825933]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1750, 1)
# mean_base [368898.87241917785]
# epochs_base_np.shape (7, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (750, 1)
# mean_base [1259936.4577672984]
# epochs_base_np.shape (3, 250, 1)
# (32, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [267268.086887326]
# epochs_base_np.shape (5, 250, 1)
# (32, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [158233.4749857515]
# epochs_base_np.shape (5, 250, 1)
# (31, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [101993.62401111948]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [186899.36894227433]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [641217.4751919229]
# epochs_base_np.shape (5, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [206696.06553923583]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [561948.145556354]
# epochs_base_np.shape (4, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# power_matrix_np (1, 300, 1)
# (1000, 1)
# mean_base [61802.44825733169]
# epochs_base_np.shape (4, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [57716.63751127253]
# epochs_base_np.shape (6, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [89489.538006786]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1750, 1)
# mean_base [179403.75970457058]
# epochs_base_np.shape (7, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (750, 1)
# mean_base [119820.98576924107]
# epochs_base_np.shape (3, 250, 1)
# (32, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [70584.59004932788]
# epochs_base_np.shape (5, 250, 1)
# (32, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [72651.23439813593]
# epochs_base_np.shape (5, 250, 1)
# (31, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [79485.6767131208]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [117871.79779339158]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [151353.46483907913]
# epochs_base_np.shape (5, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [115621.12805578341]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [184554.50644581617]
# epochs_base_np.shape (4, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# power_matrix_np (2, 300, 1)
# (1000, 1)
# mean_base [15248.468264825226]
# epochs_base_np.shape (4, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [17191.37350341935]
# epochs_base_np.shape (6, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [28979.25082340439]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1750, 1)
# mean_base [34357.69378964308]
# epochs_base_np.shape (7, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (750, 1)
# mean_base [18406.66251868488]
# epochs_base_np.shape (3, 250, 1)
# (32, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [28665.664502662046]
# epochs_base_np.shape (5, 250, 1)
# (32, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [16119.480889306402]
# epochs_base_np.shape (5, 250, 1)
# (31, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [24183.131982701743]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [17672.88913185098]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [45041.55005119814]
# epochs_base_np.shape (5, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [19727.991998953516]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [39880.32333813557]
# epochs_base_np.shape (4, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# power_matrix_np (3, 300, 1)
# (1000, 1)
# mean_base [16609.1966515721]
# epochs_base_np.shape (4, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [12330.305720532338]
# epochs_base_np.shape (6, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [11643.852134821984]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1750, 1)
# mean_base [23428.809597909498]
# epochs_base_np.shape (7, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (750, 1)
# mean_base [11638.578032342175]
# epochs_base_np.shape (3, 250, 1)
# (32, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [22298.46961079611]
# epochs_base_np.shape (5, 250, 1)
# (32, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [12831.21373253499]
# epochs_base_np.shape (5, 250, 1)
# (31, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [13193.542869305544]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [11440.197087274873]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [18959.128202431966]
# epochs_base_np.shape (5, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [10043.474411240724]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [22137.483015436086]
# epochs_base_np.shape (4, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# power_matrix_np (4, 300, 1)
# (1000, 1)
# mean_base [10663.183551070168]
# epochs_base_np.shape (4, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [8856.327226760095]
# epochs_base_np.shape (6, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [9473.06289368195]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1750, 1)
# mean_base [16318.900358525712]
# epochs_base_np.shape (7, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (750, 1)
# mean_base [8941.899990355863]
# epochs_base_np.shape (3, 250, 1)
# (32, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [17407.489057938816]
# epochs_base_np.shape (5, 250, 1)
# (32, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [9543.208949855245]
# epochs_base_np.shape (5, 250, 1)
# (31, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [8878.722894536426]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [10369.59919883668]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [14749.320864363355]
# epochs_base_np.shape (5, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [8719.29064377044]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [15027.754003329559]
# epochs_base_np.shape (4, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# power_matrix_np (5, 300, 1)
# (1000, 1)
# mean_base [10531.908642608583]
# epochs_base_np.shape (4, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [9983.508973601696]
# epochs_base_np.shape (6, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [16460.325513406853]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1750, 1)
# mean_base [15447.733580371567]
# epochs_base_np.shape (7, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (750, 1)
# mean_base [10021.81983504993]
# epochs_base_np.shape (3, 250, 1)
# (32, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [23125.6269930936]
# epochs_base_np.shape (5, 250, 1)
# (32, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [9425.652238380568]
# epochs_base_np.shape (5, 250, 1)
# (31, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [9639.337347952141]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [13346.208435885876]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [21433.740384718145]
# epochs_base_np.shape (5, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [14393.33089866372]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [15075.964737133016]
# epochs_base_np.shape (4, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# power_matrix_np (6, 300, 1)
# (1000, 1)
# mean_base [11430.615792475353]
# epochs_base_np.shape (4, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [9547.008066542001]
# epochs_base_np.shape (6, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [15825.701349661847]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1750, 1)
# mean_base [12453.671055270497]
# epochs_base_np.shape (7, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (750, 1)
# mean_base [10594.87689350307]
# epochs_base_np.shape (3, 250, 1)
# (32, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [20169.712835792026]
# epochs_base_np.shape (5, 250, 1)
# (32, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [8740.410694097482]
# epochs_base_np.shape (5, 250, 1)
# (31, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [9988.53028630628]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [15436.324366411329]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [21338.196831346573]
# epochs_base_np.shape (5, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [12194.238913665029]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [10099.676343220392]
# epochs_base_np.shape (4, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# power_matrix_np (7, 300, 1)
# (1000, 1)
# mean_base [7054.544182634035]
# epochs_base_np.shape (4, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [5160.209787095663]
# epochs_base_np.shape (6, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [7732.9217468852985]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1750, 1)
# mean_base [5395.8371010326555]
# epochs_base_np.shape (7, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (750, 1)
# mean_base [5185.2459970463415]
# epochs_base_np.shape (3, 250, 1)
# (32, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [9910.998722339438]
# epochs_base_np.shape (5, 250, 1)
# (32, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [4556.750996041069]
# epochs_base_np.shape (5, 250, 1)
# (31, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [5097.102578117185]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [7543.826170780532]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [9882.198180401385]
# epochs_base_np.shape (5, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [5016.048228691351]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [4504.627401845662]
# epochs_base_np.shape (4, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# power_matrix_np (8, 300, 1)
# (1000, 1)
# mean_base [2668.5738219864706]
# epochs_base_np.shape (4, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [2168.8097251903137]
# epochs_base_np.shape (6, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [2586.7767260234127]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1750, 1)
# mean_base [2265.087568487868]
# epochs_base_np.shape (7, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (750, 1)
# mean_base [2603.0536159624394]
# epochs_base_np.shape (3, 250, 1)
# (32, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [3986.9793706908504]
# epochs_base_np.shape (5, 250, 1)
# (32, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [1912.632213074379]
# epochs_base_np.shape (5, 250, 1)
# (31, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [2280.220501814014]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [2301.902410089477]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [2980.808209854159]
# epochs_base_np.shape (5, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [1981.2269346699509]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [2123.021421326029]
# epochs_base_np.shape (4, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# power_matrix_np (9, 300, 1)
# (1000, 1)
# mean_base [1057.7000851514179]
# epochs_base_np.shape (4, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [839.9866864719388]
# epochs_base_np.shape (6, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [1120.5587437939298]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1750, 1)
# mean_base [1175.9543077730061]
# epochs_base_np.shape (7, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (750, 1)
# mean_base [1217.4921392988476]
# epochs_base_np.shape (3, 250, 1)
# (32, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [1615.5774764065236]
# epochs_base_np.shape (5, 250, 1)
# (32, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [830.0825270120848]
# epochs_base_np.shape (5, 250, 1)
# (31, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [1172.8378525005496]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [952.8691704917414]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [1176.1969978944564]
# epochs_base_np.shape (5, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [1119.349905018094]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [858.7035440936359]
# epochs_base_np.shape (4, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# power_matrix_np (10, 300, 1)
# (1000, 1)
# mean_base [522.6747972029113]
# epochs_base_np.shape (4, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [318.0912796711427]
# epochs_base_np.shape (6, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [536.865402447513]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1750, 1)
# mean_base [550.7741296464042]
# epochs_base_np.shape (7, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (750, 1)
# mean_base [501.4172407881866]
# epochs_base_np.shape (3, 250, 1)
# (32, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [586.73025401697]
# epochs_base_np.shape (5, 250, 1)
# (32, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [404.6771124125994]
# epochs_base_np.shape (5, 250, 1)
# (31, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [476.6192139395383]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [454.9365332741719]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [550.9805680175684]
# epochs_base_np.shape (5, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [510.62320363436135]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [487.7562690099931]
# epochs_base_np.shape (4, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# power_matrix_np (11, 300, 1)
# (1000, 1)
# mean_base [252.06450429300142]
# epochs_base_np.shape (4, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [126.29271557417054]
# epochs_base_np.shape (6, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [202.41408960467558]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1750, 1)
# mean_base [197.95066608253615]
# epochs_base_np.shape (7, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (750, 1)
# mean_base [232.27335939028154]
# epochs_base_np.shape (3, 250, 1)
# (32, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [191.41728759803897]
# epochs_base_np.shape (5, 250, 1)
# (32, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [178.00072530389187]
# epochs_base_np.shape (5, 250, 1)
# (31, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [146.67840630536048]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [164.70235722023]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [218.449100031382]
# epochs_base_np.shape (5, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [168.97590535038427]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [259.3420428607991]
# epochs_base_np.shape (4, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# power_matrix_np (12, 300, 1)
# (1000, 1)
# mean_base [122.65754734644686]
# epochs_base_np.shape (4, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [45.66454341335155]
# epochs_base_np.shape (6, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [78.66331167588456]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1750, 1)
# mean_base [67.5243547436045]
# epochs_base_np.shape (7, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (750, 1)
# mean_base [98.73828106685512]
# epochs_base_np.shape (3, 250, 1)
# (32, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [65.69424144878462]
# epochs_base_np.shape (5, 250, 1)
# (32, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [55.1801871031236]
# epochs_base_np.shape (5, 250, 1)
# (31, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [40.311228144980745]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [45.73328216278208]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [96.57632373554729]
# epochs_base_np.shape (5, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [65.87214948538148]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [104.41514107419884]
# epochs_base_np.shape (4, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# power_matrix_np (13, 300, 1)
# (1000, 1)
# mean_base [98.60004265874409]
# epochs_base_np.shape (4, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [30.29567056813268]
# epochs_base_np.shape (6, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [64.92949380405376]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1750, 1)
# mean_base [36.03184440318581]
# epochs_base_np.shape (7, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (750, 1)
# mean_base [57.12644830949658]
# epochs_base_np.shape (3, 250, 1)
# (32, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [34.53834434892174]
# epochs_base_np.shape (5, 250, 1)
# (32, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [25.01659621485742]
# epochs_base_np.shape (5, 250, 1)
# (31, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [30.89875260736079]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [28.73779388642092]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [66.60059874184707]
# epochs_base_np.shape (5, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [43.231797823919905]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [72.24573176277508]
# epochs_base_np.shape (4, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# power_matrix_np (14, 300, 1)
# (1000, 1)
# mean_base [121.23201390843057]
# epochs_base_np.shape (4, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [43.27839092675363]
# epochs_base_np.shape (6, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [96.07353766007802]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1750, 1)
# mean_base [43.53051535254694]
# epochs_base_np.shape (7, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (750, 1)
# mean_base [64.71184053157377]
# epochs_base_np.shape (3, 250, 1)
# (32, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [37.46223962204205]
# epochs_base_np.shape (5, 250, 1)
# (32, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [45.0915864068442]
# epochs_base_np.shape (5, 250, 1)
# (31, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [63.54016522241583]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [54.217266979326624]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [87.57941430416987]
# epochs_base_np.shape (5, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [54.56433925341589]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [82.09581520624329]
# epochs_base_np.shape (4, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# power_matrix_np (15, 300, 1)
# (1000, 1)
# mean_base [167.05877724826203]
# epochs_base_np.shape (4, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [60.660925252306015]
# epochs_base_np.shape (6, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [120.48126575455458]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1750, 1)
# mean_base [62.68888040093068]
# epochs_base_np.shape (7, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (750, 1)
# mean_base [87.79579670327355]
# epochs_base_np.shape (3, 250, 1)
# (32, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [47.95869578383479]
# epochs_base_np.shape (5, 250, 1)
# (32, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [95.07823308771866]
# epochs_base_np.shape (5, 250, 1)
# (31, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [89.82560909596472]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [83.75302068982096]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [116.4781848964206]
# epochs_base_np.shape (5, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [80.14621813043321]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [86.6989546018446]
# epochs_base_np.shape (4, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# power_matrix_np (16, 300, 1)
# (1000, 1)
# mean_base [193.97787147210084]
# epochs_base_np.shape (4, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [73.61659808399071]
# epochs_base_np.shape (6, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [120.53040580657085]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1750, 1)
# mean_base [80.37910261037061]
# epochs_base_np.shape (7, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (750, 1)
# mean_base [100.04123344539691]
# epochs_base_np.shape (3, 250, 1)
# (32, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [51.93325074097165]
# epochs_base_np.shape (5, 250, 1)
# (32, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [127.1679423823189]
# epochs_base_np.shape (5, 250, 1)
# (31, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [81.1094197166633]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [81.1644667185598]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [118.94471222983985]
# epochs_base_np.shape (5, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [96.47226904964218]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [100.19514118596733]
# epochs_base_np.shape (4, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# power_matrix_np (17, 300, 1)
# (1000, 1)
# mean_base [187.8882694346943]
# epochs_base_np.shape (4, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [75.6893874233486]
# epochs_base_np.shape (6, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [92.4982111801268]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1750, 1)
# mean_base [76.15739313241103]
# epochs_base_np.shape (7, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (750, 1)
# mean_base [106.63321959052996]
# epochs_base_np.shape (3, 250, 1)
# (32, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [41.56686457656376]
# epochs_base_np.shape (5, 250, 1)
# (32, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [128.3288432187964]
# epochs_base_np.shape (5, 250, 1)
# (31, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [63.87567485460803]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [57.68737714216362]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [114.03405793383102]
# epochs_base_np.shape (5, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [89.70439914054407]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [141.50224811157508]
# epochs_base_np.shape (4, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# power_matrix_np (18, 300, 1)
# (1000, 1)
# mean_base [164.86178179601805]
# epochs_base_np.shape (4, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [59.732849877491525]
# epochs_base_np.shape (6, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [61.50852281646951]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1750, 1)
# mean_base [56.93439357691172]
# epochs_base_np.shape (7, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (750, 1)
# mean_base [112.99709655628598]
# epochs_base_np.shape (3, 250, 1)
# (32, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [33.71932380169678]
# epochs_base_np.shape (5, 250, 1)
# (32, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [102.35416967393544]
# epochs_base_np.shape (5, 250, 1)
# (31, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [57.50560632829129]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [41.77286165166767]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [111.53967806048175]
# epochs_base_np.shape (5, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [65.27825357813323]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [144.09197613508363]
# epochs_base_np.shape (4, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# power_matrix_np (19, 300, 1)
# (1000, 1)
# mean_base [115.11444896357696]
# epochs_base_np.shape (4, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1500, 1)
# mean_base [37.49638619189642]
# epochs_base_np.shape (6, 250, 1)
# (33, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [40.21691726504432]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1750, 1)
# mean_base [39.84194201096526]
# epochs_base_np.shape (7, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (750, 1)
# mean_base [85.85665156841878]
# epochs_base_np.shape (3, 250, 1)
# (32, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [33.08063844643557]
# epochs_base_np.shape (5, 250, 1)
# (32, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [57.76425192935183]
# epochs_base_np.shape (5, 250, 1)
# (31, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [49.926823736832844]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [29.0251953242608]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [92.31686199496268]
# epochs_base_np.shape (5, 250, 1)
# (34, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1250, 1)
# mean_base [35.54621266405579]
# epochs_base_np.shape (5, 250, 1)
# (35, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# (1000, 1)
# mean_base [97.92873848549597]
# epochs_base_np.shape (4, 250, 1)
# (36, 250, 1)
# activity_mean_epochs_concat_base (300, 1)
# baseline_corrected_activity (300, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# power_matrix_np (20, 300, 1)

# %%
# Constants
frequencies = np.arange(0, 40, 2)  # 0 to 40 Hz
cycles = np.linspace(1, 10, len(frequencies))  # Variable cycles from 1 to 10
sampling_rate = 250

power_matrix = []
for freq, cycle in zip(frequencies, cycles):
    power_blocks_base_corrected=[]
    for i in range (len(scene_np)): #12
        face_i_np= scene_np[i].to_numpy()
        face_i_np_t=np.transpose(face_i_np)

        # Extract one channel
        data_i_face_t = face_i_np_t[7, :]  # Trials are on the second dimension
        data_i_face_inst = face_i_np_t[8, :]
        wavelet = morlet_wavelet(freq, cycle, sampling_rate)
        convolution = convolve_with_wavelet(data_i_face_t , wavelet)    
        power = np.abs(convolution)**2

        data_i_face_inst_2d = data_i_face_inst[np.newaxis, :]
        power_with_inst=np.concatenate([power,data_i_face_inst_2d], axis=0)
        power_with_inst_t=np.transpose(power_with_inst)
        mask = (power_with_inst_t[:, 1] == 'b') | (power_with_inst_t[:, 1] == 'g')
        base_l= power_with_inst_t[mask]
        base= base_l[:, :-1]
        print(base.shape)
        mean_base= np.mean(base_l[:, :-1], axis=0)
        print('mean_base', mean_base)
        
        epoch_size = 250
        epochs_base = []
        for start in range(0, len(base), epoch_size):
            end = start + epoch_size
            if end <= len(base):
                epochs_base.append(base[start:end])
            else:
                epochs_base.append(base[start])
            epochs_base_np=np.array(epochs_base)
        print('epochs_base_np.shape', epochs_base_np.shape)
        
        # Calculate the mean across the first dimension, excluding the last column
        mean_epochs_base = np.mean(epochs_base_np, axis=0)

        first_200 = mean_epochs_base[:200]
        mean_base_200=np.mean(first_200, axis=0)
        
        # print('mean_base',mean_base_200)
        last_50 = mean_epochs_base[200:]
        # print('last_50', last_50)
        
        # # print('base', base.shape, base)
        activity = power_with_inst_t[~mask]
        # print('activity ', activity.shape, activity )
        
        epoch_size = 250
        epochs = []
        for start in range(0, len(activity), epoch_size):
            end = start + epoch_size
            if end <= len(activity):
                epochs.append(activity[start:end, :-1])
            else:
                epochs.append(activity[start:,:-1])
            epochs_np=np.array(epochs)
        print(epochs_np.shape)
        # Calculate the mean across the first dimension, excluding the last column
        activity_mean_epochs = np.mean(epochs_np, axis=0)
        # print('activity_mean_epochs', activity_mean_epochs.shape) #activity_mean_epochs (250, 1)
        activity_mean_epochs_concat_base=np.concatenate([last_50,activity_mean_epochs], axis=0)
        # print('activity_mean_epochs_concat_base', activity_mean_epochs_concat_base.shape) #activity_mean_epochs_concat_base (300, 1)
        baseline_corrected_activity=activity_mean_epochs_concat_base/mean_base_200
        # print('baseline_corrected_activity', baseline_corrected_activity.shape) #baseline_corrected_activity (300, 1)
        power_blocks_base_corrected.append(baseline_corrected_activity)
        # power_blocks_base_corrected_np= np.array(power_blocks_base_corrected)
        # print('power_blocks_base_corrected_np', power_blocks_base_corrected_np.shape)     
    power_blocks_base_corrected_np_mean=np.mean(power_blocks_base_corrected, axis=0)
    print('power_blocks_base_corrected_np_mean', power_blocks_base_corrected_np_mean.shape)
    power_matrix.append(power_blocks_base_corrected_np_mean)
    power_matrix_np=np.array(power_matrix)
    print('power_matrix_np', power_matrix_np.shape)
# Out:
# (1500, 1)
# mean_base [104262.52884559252]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [169112.74661285745]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [143743.62941678893]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [116310.91573832878]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [56175.795976103225]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [152807.7496278186]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [80541.71936775446]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [178944.12881709807]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [136127.02148818682]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [54944.240923371515]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1250, 1)
# mean_base [75814.14789927522]
# epochs_base_np.shape (5, 250, 1)
# (26, 250, 1)
# (1250, 1)
# mean_base [349729.4504362819]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# power_matrix_np (1, 300, 1)
# (1500, 1)
# mean_base [40504.755919805306]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [39095.47755974993]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [61397.8340699757]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [40006.32525191988]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [35258.43891295263]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [51727.49985340643]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [37108.3044731204]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [63422.01735122453]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [45761.38043577117]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [27609.60882992534]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1250, 1)
# mean_base [33210.12802004225]
# epochs_base_np.shape (5, 250, 1)
# (26, 250, 1)
# (1250, 1)
# mean_base [48182.47480858579]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# power_matrix_np (2, 300, 1)
# (1500, 1)
# mean_base [5680.741789447019]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [8162.316011248609]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [12385.117320886142]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [8514.480132559996]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [7175.51147026239]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [17016.165550327423]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [10257.636742873347]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [11568.099968889872]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [9173.946631300485]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [4959.708453359847]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1250, 1)
# mean_base [11198.361458773605]
# epochs_base_np.shape (5, 250, 1)
# (26, 250, 1)
# (1250, 1)
# mean_base [10284.63880609786]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# power_matrix_np (3, 300, 1)
# (1500, 1)
# mean_base [3037.8315625354803]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [5598.3527212972085]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [4490.726811520387]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [5738.204450011344]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [3220.0771101918554]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [7911.121646041265]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [5729.825746621548]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [7459.046334347728]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [3834.4503892562334]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [3359.7240741984447]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1250, 1)
# mean_base [9360.410857945297]
# epochs_base_np.shape (5, 250, 1)
# (26, 250, 1)
# (1250, 1)
# mean_base [5783.947991458066]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# power_matrix_np (4, 300, 1)
# (1500, 1)
# mean_base [3745.858214997965]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [5432.620967343529]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [6704.112058876301]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [4761.219767163447]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [3105.8382331310554]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [5434.701064161591]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [4701.942953847684]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [10637.293585090494]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [4631.548962527741]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [5363.950452555755]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1250, 1)
# mean_base [6925.463992057842]
# epochs_base_np.shape (5, 250, 1)
# (26, 250, 1)
# (1250, 1)
# mean_base [6277.071610243391]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# power_matrix_np (5, 300, 1)
# (1500, 1)
# mean_base [4579.013129143548]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [7163.878175146279]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [12417.451209071927]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [6875.047914390954]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [4720.530233591173]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [7565.464523199729]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [6452.524597024796]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [19471.72503840566]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [8002.8873087242255]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [9540.821940534699]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1250, 1)
# mean_base [9405.77516098843]
# epochs_base_np.shape (5, 250, 1)
# (26, 250, 1)
# (1250, 1)
# mean_base [11060.26217666944]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# power_matrix_np (6, 300, 1)
# (1500, 1)
# mean_base [5067.759814103049]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [8932.680055612822]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [13163.823889825084]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [7361.430090612211]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [5944.266005221748]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [9178.322849617613]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [6451.072123338468]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [18590.72954437795]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [8625.561175393283]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [9655.334394258929]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1250, 1)
# mean_base [11788.669517700508]
# epochs_base_np.shape (5, 250, 1)
# (26, 250, 1)
# (1250, 1)
# mean_base [14201.41048016372]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# power_matrix_np (7, 300, 1)
# (1500, 1)
# mean_base [3128.98467865769]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [5562.807461298855]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [6488.725710799472]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [3716.292164467977]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [3413.2436391111805]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [5826.45154354538]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [3163.059796080015]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [7711.24273933891]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [4432.1627272332125]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [4215.732916902512]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1250, 1)
# mean_base [6046.440148842861]
# epochs_base_np.shape (5, 250, 1)
# (26, 250, 1)
# (1250, 1)
# mean_base [7048.521001424634]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# power_matrix_np (8, 300, 1)
# (1500, 1)
# mean_base [1358.9568922380863]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [1859.0658441479559]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [1871.6258005713773]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [1266.6479898383532]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [1253.1763787289208]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [2380.590236374112]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [1169.3197841536003]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [2370.504596006274]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [1390.8028825827798]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [1311.2166071041868]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1250, 1)
# mean_base [2143.8952310702734]
# epochs_base_np.shape (5, 250, 1)
# (26, 250, 1)
# (1250, 1)
# mean_base [2145.926884584036]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# power_matrix_np (9, 300, 1)
# (1500, 1)
# mean_base [588.605609469059]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [629.8463594487748]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [601.3140232038189]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [498.1011921767592]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [614.8248207840521]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [899.9123349028627]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [467.85454824329076]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [794.4451168462156]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [460.2666452338137]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [586.46131981621]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1250, 1)
# mean_base [1074.7893370923011]
# epochs_base_np.shape (5, 250, 1)
# (26, 250, 1)
# (1250, 1)
# mean_base [690.6592424121734]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# power_matrix_np (10, 300, 1)
# (1500, 1)
# mean_base [226.1074945187694]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [284.4631640921102]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [291.74260576546726]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [209.48088646762235]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [311.2835922548723]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [292.0940868341158]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [203.6910864318498]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [327.28722033784163]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [215.78200814294334]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [302.5974210992498]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1250, 1)
# mean_base [599.4505425499084]
# epochs_base_np.shape (5, 250, 1)
# (26, 250, 1)
# (1250, 1)
# mean_base [275.9010501827539]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# power_matrix_np (11, 300, 1)
# (1500, 1)
# mean_base [77.24871254182557]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [108.68847600391628]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [113.1558091514109]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [79.66141304112034]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [118.67694054981325]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [89.80438693636582]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [87.47375527847886]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [142.74178154210324]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [88.87376699175603]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [110.1934944260444]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1250, 1)
# mean_base [251.18557006259834]
# epochs_base_np.shape (5, 250, 1)
# (26, 250, 1)
# (1250, 1)
# mean_base [150.5571255572345]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# power_matrix_np (12, 300, 1)
# (1500, 1)
# mean_base [26.3416700934341]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [35.37049256399315]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [37.520774800019986]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [31.160651602659843]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [34.89820367230301]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [33.52872447816964]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [34.778709652816545]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [50.44640381890006]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [29.058628514828776]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [31.30565067473033]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1250, 1)
# mean_base [123.32461662234692]
# epochs_base_np.shape (5, 250, 1)
# (26, 250, 1)
# (1250, 1)
# mean_base [89.69473975033243]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# power_matrix_np (13, 300, 1)
# (1500, 1)
# mean_base [27.125452453837127]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [26.958530044385707]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [25.6814475846682]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [19.53546538757332]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [22.99905260943586]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [21.217825434282627]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [20.96597401541842]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [29.783307002176496]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [18.25808660330925]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [20.44361741861553]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1250, 1)
# mean_base [98.13030234920755]
# epochs_base_np.shape (5, 250, 1)
# (26, 250, 1)
# (1250, 1)
# mean_base [54.84661972489784]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# power_matrix_np (14, 300, 1)
# (1500, 1)
# mean_base [56.10742302943357]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [52.29724874918026]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [42.56376076752371]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [31.390284390735847]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [49.83410095839307]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [35.87772230164117]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [32.23980255426951]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [44.74947911270559]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [36.25731549792502]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [37.65959089050372]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1250, 1)
# mean_base [91.90788922292974]
# epochs_base_np.shape (5, 250, 1)
# (26, 250, 1)
# (1250, 1)
# mean_base [52.32274953432696]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# power_matrix_np (15, 300, 1)
# (1500, 1)
# mean_base [80.27131168083851]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [90.62095928979663]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [76.43286519130217]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [49.0633141137419]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [80.43126856055997]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [63.08800752476964]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [50.48360677207933]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [59.48378237687899]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [58.04856743869072]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [53.64246396724878]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1250, 1)
# mean_base [91.32056329091634]
# epochs_base_np.shape (5, 250, 1)
# (26, 250, 1)
# (1250, 1)
# mean_base [54.67569927646825]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# power_matrix_np (16, 300, 1)
# (1500, 1)
# mean_base [77.2020260962761]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [121.37414647590501]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [99.57440477317782]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [62.12305679460374]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [87.58355181212183]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [93.82279320409826]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [65.63706296986665]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [78.49426499913642]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [57.903476600321326]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [68.0366389434707]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1250, 1)
# mean_base [101.87974372145773]
# epochs_base_np.shape (5, 250, 1)
# (26, 250, 1)
# (1250, 1)
# mean_base [51.950055209780814]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# power_matrix_np (17, 300, 1)
# (1500, 1)
# mean_base [69.71745076827536]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [134.8988011264071]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [86.21009941955865]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [73.447709267504]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [80.15519536343506]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [104.30481822642018]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [65.12814672212278]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [99.79714500854399]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [54.8126614216509]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [72.84170928869088]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1250, 1)
# mean_base [105.63145334089704]
# epochs_base_np.shape (5, 250, 1)
# (26, 250, 1)
# (1250, 1)
# mean_base [50.85190335546785]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# power_matrix_np (18, 300, 1)
# (1500, 1)
# mean_base [71.64965204443477]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [117.52969957979077]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [65.47059152974916]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [68.94545894334571]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [70.47954719550039]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [75.06188288236609]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [49.4121519733689]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [84.32687401820972]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [55.7771126522112]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [57.981648962207885]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1250, 1)
# mean_base [88.04465618751242]
# epochs_base_np.shape (5, 250, 1)
# (26, 250, 1)
# (1250, 1)
# mean_base [47.43474020979935]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# power_matrix_np (19, 300, 1)
# (1500, 1)
# mean_base [57.69440222421161]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [72.39389816521704]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [45.60275016823546]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [47.59952944734461]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [59.368729638512384]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [48.33811244874372]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [33.76749306688214]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [53.442243730388235]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [53.9878844959761]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1500, 1)
# mean_base [41.353924480364434]
# epochs_base_np.shape (6, 250, 1)
# (40, 250, 1)
# (1250, 1)
# mean_base [64.7127986430144]
# epochs_base_np.shape (5, 250, 1)
# (26, 250, 1)
# (1250, 1)
# mean_base [45.40336663115304]
# epochs_base_np.shape (5, 250, 1)
# (37, 250, 1)
# power_blocks_base_corrected_np_mean (300, 1)
# power_matrix_np (20, 300, 1)

# %%
np.savetxt("power_matrix_Face_fz.csv", power_matrix_np.reshape(20,300), delimiter=",")

# %%
np.savetxt("power_matrix_Scene_fz.csv", power_matrix_np.reshape(20,300),delimiter=",")

# %%
current_directory = os.getcwd()
print(current_directory)
# Out:
# c:\Users\Maryam\Documents\GitHub\Neurofeedback-Based-BCI_r\SVM for Unicorn Data

# %%
# Loop over each frequency
# Get the current working directory
import os
import pandas as pd


# Name of the file
file_name = 'power_matrix_Face_Pz.csv'

# Construct the full file path including the folder name
file_path = os.path.join(current_directory,  file_name)

# Load the data from the CSV file
data_df = pd.read_csv(file_path)

# Convert DataFrame to NumPy array for plotting
data_np = data_df.to_numpy()

# Slice the array to exclude the first 50 columns
data = data_np[:, 50:]

# %%
# Loop over each frequency
# Get the current working directory
import os
import pandas as pd


# Name of the file
file_name = 'power_matrix_Scene_Pz.csv'

# Construct the full file path including the folder name
file_path = os.path.join(current_directory, file_name)

# Load the data from the CSV file
data_df = pd.read_csv(file_path)

# Convert DataFrame to NumPy array for plotting
data_np = data_df.to_numpy()

# Slice the array to exclude the first 50 columns
data = data_np[:, 50:]

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt



# Define the plotting function
def plot_time_frequency(data, title):
    plt.figure(figsize=(5, 4))
    plt.imshow(10*np.log10(data), aspect='auto', cmap='jet', origin='lower',
               extent=[times[0], times[249], frequencies[0], frequencies[-1]], vmin=-2, vmax=2)  # Log transform of power; color limits as specified
    plt.colorbar(format='%+2.0f dB')
    plt.xlabel('Time (ms)')
    plt.ylabel('Frequency (Hz)')
    plt.title(title)
    plt.tight_layout()
    plt.show()

# Constants for plotting
frequencies = np.arange(1, 40, 1)  # 0 to 40 Hz in steps of 2
sampling_rate = 250  # Sampling rate
sampling_interval = 1 / sampling_rate  # Sampling interval
times = np.arange(0, 1, step=sampling_interval) * 1000  # Convert to milliseconds


# Plot the results
plot_time_frequency(data, 'Face (Pz) ')

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt



# Define the plotting function
def plot_time_frequency(data, title):
    plt.figure(figsize=(5, 4))
    plt.imshow(10*np.log10(data), aspect='auto', cmap='jet', origin='lower',
               extent=[times[0], times[249], frequencies[0], frequencies[-1]], vmin=-2, vmax=2)  # Log transform of power; color limits as specified
    plt.colorbar(format='%+2.0f dB')
    plt.xlabel('Time (ms)')
    plt.ylabel('Frequency (Hz)')
    plt.title(title)
    plt.tight_layout()
    plt.show()

# Constants for plotting
frequencies = np.arange(1, 40, 1)  # 0 to 40 Hz in steps of 2
sampling_rate = 250  # Sampling rate
sampling_interval = 1 / sampling_rate  # Sampling interval
times = np.arange(0, 1, step=sampling_interval) * 1000  # Convert to milliseconds


# Plot the results
plot_time_frequency(data, 'Scene (Pz)')

# %%
power_matrix_files = [file for file in os.listdir(current_directory) if file.startswith('power_matrix_') and file.endswith('.csv')]
len(power_matrix_files)
# Out:
# 16

# %%
import optuna
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split


def objective(trial):
    # Layers and neurons
    n_layers = trial.suggest_int('n_layers', 1,3)
    layers = []
    for i in range(n_layers):
        layers.append(trial.suggest_int(f'n_units_layer{i}', 16,  512))
    
    # Activation function
    activation = trial.suggest_categorical('activation', ['relu', 'logistic', 'tanh', 'identity'])
    
    # Learning rate
    learning_rate_init = trial.suggest_float('learning_rate_init', 1e-4,  1e-1, log=True)
    
    max_iter = trial.suggest_int('max_iter', 50, 1000)

    model = MLPClassifier(hidden_layer_sizes=tuple(layers), 
                          activation=activation, 
                          learning_rate_init=learning_rate_init,
                          max_iter=max_iter ,  # to ensure convergence in most cases
                          random_state=42)

    model.fit(X_train_mlp, y_train_mlp)

    # Evaluate
    predictions = model.predict(X_test_mlp)
    accuracy = accuracy_score(y_test_mlp, predictions)
    return accuracy

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=70)

print('Number of finished trials: ', len(study.trials))
print('Best trial:')
trial = study.best_trial
print('  Value: ', trial.value)
print('  Params: ')
for key, value in trial.params.items():
    print(f'    {key}: {value}')

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import classification_report, accuracy_score
import pandas as pd
import numpy as np
import os

def load_and_extract_features(file_path):
    # Load the data
    data = pd.read_csv(file_path)
    
    # Calculate summary statistics for each trial (row in the CSV)
    features = data.agg(['mean', 'std', 'min', 'max', 'median']).transpose()
    
    return features

# Initialize lists to store features and labels
all_features = []
all_labels = []
current_directory = os.getcwd()
power_matrix_files = [file for file in os.listdir(current_directory) if file.startswith('power_matrix_') and file.endswith('.csv')]

# Process each file and extract features
for file_name in power_matrix_files:
    file_path = os.path.join(current_directory, file_name)
    features = load_and_extract_features(file_path)
    all_features.append(features)
    label = 1 if 'Face' in file_name else 0
    all_labels.extend([label] * len(features))

# Combine all features into a single dataframe and convert labels to a NumPy array
all_features_df = pd.concat(all_features)
all_labels = np.array(all_labels)

# Split the dataset into training+validation and testing sets
X_train_val, X_test, y_train_val, y_test = train_test_split(all_features_df, all_labels, test_size=0.2, random_state=42)

# Further split the training set into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.25, random_state=42) # 0.25 x 0.8 = 0.2

# Initialize the Random Forest classifier
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)

# Train the classifier with cross-validation
cross_val_scores = cross_val_score(rf_classifier, X_train, y_train, cv=10) # 5-fold cross-validation

# Fit the model on the entire training set
rf_classifier.fit(X_train, y_train)

# Evaluate the classifier using the validation set
y_val_pred = rf_classifier.predict(X_val)
val_accuracy = accuracy_score(y_val, y_val_pred)
val_classification_rep = classification_report(y_val, y_val_pred)

# Output the validation accuracy and classification report
print("Validation Results:")
print(f"Cross-Validation Scores: {cross_val_scores}")
print(f"Validation Accuracy: {val_accuracy}")
print(val_classification_rep)

# Test the classifier using the test set
y_test_pred = rf_classifier.predict(X_test)
test_accuracy = accuracy_score(y_test, y_test_pred)
test_classification_rep = classification_report(y_test, y_test_pred)

# Output the test accuracy and classification report
print("\nTest Results:")
print(f"Test Accuracy: {test_accuracy}")
print(test_classification_rep)
# Out:
# Validation Results:
# Cross-Validation Scores: [0.95486111 0.97222222 0.95486111 0.96180556 0.95486111 0.98263889
#  0.94444444 0.96875    0.97222222 0.96180556]
# Validation Accuracy: 0.9666666666666667
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97       488
#            1       0.97      0.96      0.97       472
#
#     accuracy                           0.97       960
#    macro avg       0.97      0.97      0.97       960
# weighted avg       0.97      0.97      0.97       960
#
#
# Test Results:
# Test Accuracy: 0.98125
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       472
#            1       0.98      0.98      0.98       488
#
#     accuracy                           0.98       960
#    macro avg       0.98      0.98      0.98       960
# weighted avg       0.98      0.98      0.98       960

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming all_features_df is your dataframe containing all the features

# 1. Histograms
all_features_df.hist(figsize=(12, 10))
plt.tight_layout()
plt.show()

# 2. Box plots
plt.figure(figsize=(12, 6))
sns.boxplot(data=all_features_df)
plt.xticks(rotation=45)
plt.show()

# 3. Scatter plots (example for 'mean' vs 'std' of a feature)
plt.figure(figsize=(6, 6))
sns.scatterplot(x='mean', y='std', data=all_features_df, hue=all_labels)
plt.show()

# 4. Pair plots (might be computationally expensive with many features)
# sns.pairplot(all_features_df, hue=all_labels)  # Uncomment to use

# 5. Heatmap of Correlation Matrix
plt.figure(figsize=(10, 8))
sns.heatmap(all_features_df.corr(), annot=True, fmt=".2f", cmap="Blues")
plt.show()

# %%
import numpy as np
from scipy.optimize import minimize_scalar

# Define the MGF of the Laplace distribution for the given range of t
def mgf_laplace(t):
    return 1 / (1 - t**2) if abs(t) < 1 else np.inf

# Define the Chernoff bound function
def chernoff_bound(t, n):
    return np.exp(-t * n) * (mgf_laplace(t))**n

# Choose a large value for n, for example, n = 1000
n_large = 1000

# Perform the minimization using scipy's minimize_scalar function
# within the bounds of t where the MGF is valid
res = minimize_scalar(chernoff_bound, bounds=(-0.99, 0.99), args=(n_large,), method='bounded')

# Check the result
if res.success:
    optimal_t = res.x
    minimal_bound = res.fun
else:
    optimal_t = None
    minimal_bound = None

optimal_t, minimal_bound
# Out:
# (0.4142132480622706, 7.1618497535980695e-99)
